# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns

from sportsreference.ncaab.roster import Roster as ncaa_roster
from sportsreference.ncaab.teams import Teams as ncaa_teams

from sportsreference.nba.roster import Roster as nba_roster
from sportsreference.nba.teams import Teams as nba_teams

from IPython.display import clear_output

# %%
draft_data=pd.read_csv('draft.csv')

# %%
draft_data.head()
# Out:
#     Rk    Year   Lg   Rd   Pk   Tm         Player     Age Pos Born  ...   TRB  \
# 0  1.0  2018.0  NBA  1.0  1.0  PHO  Deandre Ayton  19.338   C   bs  ...  10.3
# 1  2.0  2018.0  NBA  1.0  2.0  SAC  Marvin Bagley  19.104   F   us  ...   7.6
# 2  3.0  2018.0  NBA  1.0  4.0  MEM  Jaren Jackson  18.284   F   us  ...   4.7
# 3  4.0  2018.0  NBA  1.0  5.0  DAL     Trae Young  19.280   G   us  ...   3.7
# 4  5.0  2018.0  NBA  1.0  6.0  ORL  Mohamed Bamba  20.045   C   us  ...   5.0
#
#    AST  STL  BLK    FG%    2P%    3P%    FT%   WS  WS/48
# 0  1.8  0.9  0.9  0.585  0.588  0.000  0.746  5.8  0.128
# 1  1.0  0.5  1.0  0.504  0.534  0.313  0.691  3.6  0.110
# 2  1.1  0.9  1.4  0.506  0.553  0.359  0.766  3.3  0.105
# 3  8.1  0.9  0.2  0.418  0.477  0.324  0.829  3.3  0.062
# 4  0.8  0.3  1.4  0.481  0.555  0.300  0.587  1.7  0.106
#
# [5 rows x 26 columns]

# %%
draft_data=draft_data.drop([3086,3087],axis=0)


draft_data['Year']=draft_data.Year.astype(int)
draft_data['Rd']=draft_data.Rd.astype(int)
draft_data['Pk']=draft_data.Pk.astype(int)

# %%
data=draft_data[draft_data.From>0]
data
# Out:
#           Rk  Year   Lg  Rd   Pk   Tm                   Player     Age  Pos  \
# 0        1.0  2018  NBA   1    1  PHO            Deandre Ayton  19.338    C
# 1        2.0  2018  NBA   1    2  SAC            Marvin Bagley  19.104    F
# 2        3.0  2018  NBA   1    4  MEM            Jaren Jackson  18.284    F
# 3        4.0  2018  NBA   1    5  DAL               Trae Young  19.280    G
# 4        5.0  2018  NBA   1    6  ORL            Mohamed Bamba  20.045    C
# 5        6.0  2018  NBA   1    7  CHI           Wendell Carter  19.071    C
# 6        7.0  2018  NBA   1    8  CLE            Collin Sexton  19.173    G
# 7        8.0  2018  NBA   1    9  NYK               Kevin Knox  18.319    F
# 8        9.0  2018  NBA   1   10  PHI            Mikal Bridges  21.300    G
# 9       10.0  2018  NBA   1   11  CHO  Shai Gilgeous-Alexander  19.349    G
# 10      11.0  2018  NBA   1   12  LAC            Miles Bridges  20.097  G-F
# 11      12.0  2018  NBA   1   13  LAC          Jerome Robinson  21.124    G
# 13      14.0  2018  NBA   1   15  WAS               Troy Brown  18.333  G-F
# 14      15.0  2018  NBA   1   16  PHO             Zhaire Smith  19.022    G
# 15      16.0  2018  NBA   1   17  MIL         Donte DiVincenzo  21.146    G
# 16      17.0  2018  NBA   1   18  SAS            Lonnie Walker  19.194    G
# 17      18.0  2018  NBA   1   19  ATL            Kevin Huerter  19.303    G
# 3012   us  ...   1.3  3.5  0.8  0.1  0.464  0.479  0.211  0.749   8.0  0.074
# 3039   us  ...   1.8  0.5  0.1  0.3  0.369  0.378  0.000  0.667  -0.1 -0.010
# 3040   us  ...   2.5  0.4  0.2  0.1  0.485  0.488  0.000  0.692   1.0  0.107
# 3053   us  ...   1.0  1.2  0.6  0.1  0.454  0.467  0.000  0.564  -0.6 -0.050
#
# [1809 rows x 26 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1809 entries, 0 to 3053
# Data columns (total 26 columns):
# Rk         1809 non-null float64
# Year       1809 non-null int32
# Lg         1809 non-null object
# Rd         1809 non-null int32
# Pk         1809 non-null int32
# Tm         1809 non-null object
# Player     1809 non-null object
# Age        1809 non-null float64
# Pos        1809 non-null object
# Born       1809 non-null object
# College    1809 non-null object
# From       1809 non-null float64
# To         1809 non-null float64
# G          1809 non-null float64
# MP         1809 non-null float64
# PTS        1809 non-null float64
# TRB        1809 non-null float64
# AST        1809 non-null float64
# STL        1809 non-null float64
# BLK        1809 non-null float64
# FG%        1804 non-null float64
# 2P%        1802 non-null float64
# 3P%        1635 non-null float64
# FT%        1768 non-null float64
# WS         1809 non-null float64
# WS/48      1808 non-null float64
# dtypes: float64(17), int32(3), object(6)
# memory usage: 360.4+ KB

# %%
data=data.dropna(subset=['3P%'])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1635 entries, 0 to 3053
# Data columns (total 26 columns):
# Rk         1635 non-null float64
# Year       1635 non-null int32
# Lg         1635 non-null object
# Rd         1635 non-null int32
# Pk         1635 non-null int32
# Tm         1635 non-null object
# Player     1635 non-null object
# Age        1635 non-null float64
# Pos        1635 non-null object
# Born       1635 non-null object
# College    1635 non-null object
# From       1635 non-null float64
# To         1635 non-null float64
# G          1635 non-null float64
# MP         1635 non-null float64
# PTS        1635 non-null float64
# TRB        1635 non-null float64
# AST        1635 non-null float64
# STL        1635 non-null float64
# BLK        1635 non-null float64
# FG%        1635 non-null float64
# 2P%        1633 non-null float64
# 3P%        1635 non-null float64
# FT%        1621 non-null float64
# WS         1635 non-null float64
# WS/48      1635 non-null float64
# dtypes: float64(17), int32(3), object(6)
# memory usage: 325.7+ KB

# %%
data=data.drop('Lg',axis=1)
data=data.drop('Rk',axis=1)

# %%
college_teams=ncaa_teams().dataframes

# %%
data['college_code']=data['College'].str.replace('University','')
data['college_code']=data['college_code'].str.replace('of ','')
data['college_code']=data['college_code'].str.replace(',','')
data['college_code']=data['college_code'].str.replace('.','')
data['college_code']=data['college_code'].str.replace('\'','')
data['college_code']=data['college_code'].str.replace('College','')
data['college_code']=data['college_code'].str.strip()
data['college_code']=data['college_code'].str.upper()
data['college_code']=data['college_code'].str.replace('   ','-')
data['college_code']=data['college_code'].str.replace('  ','-')
data['college_code']=data['college_code'].str.replace(' ','-')
data['college_code']=data['college_code'].str.replace('AT-','')
data['college_code']=data['college_code'].str.replace('CALIFORNIA-STATE','CAL-STATE')
data['college_code']=data['college_code'].str.replace('A&M','AM')
data['college_code']=data['college_code'].str.replace('THE-','')

data['Player']=data['Player'].str.replace('.','')

# %%
code_set=set(college_teams.abbreviation)

for i in data[data.college_code=='CALIFORNIA-LOS-ANGELES'].index:
    data.loc[i,'college_code']='UCLA'

for i in data[data.college_code=='ILLINOIS-URBANA-CHAMPAIGN'].index:
    data.loc[i,'college_code']='ILLINOIS'
    
for i in data[data.college_code=='NEVADA-RENO'].index:
    data.loc[i,'college_code']='NEVADA'

for i in data[data.college_code=='GEORGIA-INSTITUTE-TECHNOLOGY'].index:
    data.loc[i,'college_code']='GEORGIA-TECH'    
    
for i in data[data.College=='Boston College'].index:
    data.loc[i,'college_code']='BOSTON-COLLEGE'    
    
for i in data[data.College=='Boston University'].index:
    data.loc[i,'college_code']='BOSTON-UNIVERSITY'  
    
for i in data[data.college_code=='VIRGINIA-POLYTECHNIC-INSTITUTE-AND-STATE'].index:
    data.loc[i,'college_code']='VIRGINIA-TECH'
    
for i in data[data.college_code=='TEXAS-AUSTIN'].index:
    data.loc[i,'college_code']='TEXAS'  

for i in data[data.college_code=='ST-JOHNS'].index:
    data.loc[i,'college_code']='ST-JOHNS-NY' 
    
for i in data[data.College=='University of Miami'].index:
    data.loc[i,'college_code']='MIAMI-FL'    
    
for i in data[data.College=='Miami University'].index:
    data.loc[i,'college_code']='MIAMI-OH' 
    
for i in data[data.college_code=='LOYOLA-CHICAGO'].index:
    data.loc[i,'college_code']='LOYOLA-IL'  

for i in data[data.college_code=='LOYOLA-IN-MARYLAND'].index:
    data.loc[i,'college_code']='LOYOLA-MD' 
    
for i in data[data.college_code=='FLORIDA-AGRICULTURAL-AND-MECHANICAL'].index:
    data.loc[i,'college_code']='FLORIDA-AM' 
    
for i in data[data.college_code=='CAL-STATE-FRESNO'].index:
    data.loc[i,'college_code']='FRESNO-STATE' 
    
for i in data[data.college_code=='CAL-STATE-LONG-BEACH'].index:
    data.loc[i,'college_code']='LONG-BEACH-STATE' 
    
for i in data[data.college_code=='TENNESSEE-TECHNOLOGICAL'].index:
    data.loc[i,'college_code']='TENNESSEE-TECH' 
    
for i in data[data.college_code=='INDIANA--PURDUE-INDIANAPOLIS'].index:
    data.loc[i,'college_code']='IUPUI' 
    
for i in data[data.college_code=='SAINT-MARYS-CALIFORNIA'].index:
    data.loc[i,'college_code']='SAINT-MARYS-CA' 
    
for i in data[data.college_code=='MIDDLE-TENNESSEE-STATE'].index:
    data.loc[i,'college_code']='MIDDLE-TENNESSEE' 
    
for i in data[data.college_code=='AUSTIN-PEAY-STATE'].index:
    data.loc[i,'college_code']='AUSTIN-PEAY'  
    
for i in data[data.college_code=='MASSACHUSETTS-AMHERST'].index:
    data.loc[i,'college_code']='MASSACHUSETTS'  
    
for i in data[data.college_code=='PENNSYLVANIA-STATE'].index:
    data.loc[i,'college_code']='PENN-STATE'
    
for i in data[data.college_code=='LONG-ISLAND'].index:
    data.loc[i,'college_code']='LONG-ISLAND-UNIVERSITY'
    
for i in data[data.college_code=='UNITED-STATES-NAVAL-ACADEMY'].index:
    data.loc[i,'college_code']='NAVY'
    
for code in data.college_code:
    if code not in code_set:
        print(code)
# Out:
# CHARLESTON
# SOUTHEASTERN-ILLINOIS
# WESTERN-CAROLINA
# WESTERN-ILLINOIS
# WESTERN-KENTUCKY
# WESTERN-MICHIGAN
# WICHITA-STATE
# WILLIAM-MARY
# WINTHROP
# WISCONSIN
# WOFFORD
# WRIGHT-STATE
# WYOMING
# XAVIER
# YALE
# YOUNGSTOWN-STATE

# %%
sample_player_df=ncaa_roster(team='DUKE').players[1].dataframe

# %%
ncaa_columns=list(sample_player_df.columns)
cfirst_columns=[]
clast_columns=[]
for column in list(ncaa_columns):
    cfirst_columns.append('cfirst_'+column)
    clast_columns.append('clast_'+column)

# %%
data.keys()
# Out:
# Index(['Year', 'Rd', 'Pk', 'Tm', 'Player', 'Age', 'Pos', 'Born', 'College',
#        'From', 'To', 'G', 'MP', 'PTS', 'TRB', 'AST', 'STL', 'BLK', 'FG%',
#        '2P%', '3P%', 'FT%', 'WS', 'WS/48', 'college_code'],
#       dtype='object')

# %%
data=pd.concat([data,pd.DataFrame(columns=cfirst_columns)],sort=False)
data=pd.concat([data,pd.DataFrame(columns=clast_columns)],sort=False)
data['Year']=draft_data.Year.astype(int)
data['Rd']=draft_data.Rd.astype(int)
data['Pk']=draft_data.Pk.astype(int)

# %%
for r in data.iterrows():
    i=r[0]
    row=r[1]
    clear_output(wait=True)
    print(i)
    try:
        for player in ncaa_roster(team=row.college_code,year=row.Year).players:
            if player.name:
                if row.Player in player.name:
                    first=player.dataframe.iloc[0,:]
                    first.index=['cfirst_'+s for s in list(first.keys())]
                    data.loc[i,cfirst_columns]=first
                    last=player.dataframe.iloc[-2,:]
                    last.index=['clast_'+s for s in list(last.keys())]
                    data.loc[i,clast_columns]=last
                    break
                
        for player in ncaa_roster(team=row.college_code,year=(row.Year-1)).players:
            if player.name:
                if row.Player in player.name:
                    first=player.dataframe.iloc[0,:]
                    first.index=['cfirst_'+s for s in list(first.keys())]
                    data.loc[i,cfirst_columns]=first
                    last=player.dataframe.iloc[-2,:]
                    last.index=['clast_'+s for s in list(last.keys())]
                    data.loc[i,clast_columns]=last
                    break
                
    except:
        pass
missing_players=data[data.clast_points.isnull()].Player
missing_players
# Out:
# 3053
# 46             Ray Spalding
# 66                DJ Wilson
# 89           Damyean Dotson
# 133              AJ Hammons
# 167          Larry Nance Jr
# 168               RJ Hunter
# 180            Joseph Young
# 202               TJ Warren
# 211             PJ Hairston
# 212               CJ Wilcox
# 215            KJ McDaniels
# 219     Johnny O'Bryant III
# 223      Glenn Robinson III
# 246             CJ McCollum
# 271              Ricky Ledo
# 313             Jeff Taylor
# 353          MarShon Brooks
# 371        Andrew Goudelock
# 384          Wesley Johnson
# 458        Jeff Pendergraph
# 475                AJ Price
# 484                 OJ Mayo
# 489             DJ Augustin
# 499              JJ Hickson
# 506                DJ White
# 507              JR Giddens
# 512        Luc Mbah a Moute
# 517           Patrick Ewing
# 519             Bill Walker
# 577           DJ Strawberry
#                ...
# 1430             Greg Grant
# 1490          Nate Johnston
# 1511         Scottie Pippen
# 1538             Bob McCann
# 1554           Jamie Waller
# 1604          Ron Grandison
# 1611            Bart Kofoed
# 1687          Dennis Rodman
# 1827         Charles Oakley
# 1841               AC Green
# 1842           Terry Porter
# 1849             Manute Bol
# 1864         Gerald Wilkins
# 1974             Mario Elie
# 2018           Willie White
# 2022          Jerome Kersey
# 2038             David Pope
# 2107      Eddie Lee Wilkins
# 2130          Ken Bannister
# 2255            Mike Holton
# 2340         Sedale Threatt
# 2454            Dave Magley
# 2462            JJ Anderson
# 2471           Russ Schoene
# 2566           Eddie Hughes
# 2666            Kevin Loder
# 2799        Clinton Wheeler
# 2877           Mike O'Koren
# 2906            Rick Mahorn
# 2927            Mike Harper
# Name: Player, Length: 95, dtype: object

# %%
data.to_csv('raw_data.csv',index=False,header=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1635 entries, 0 to 3053
# Columns: 127 entries, Year to clast_win_shares_per_40_minutes
# dtypes: float64(16), int32(3), object(108)
# memory usage: 1.7+ MB

# %%
data.head()
# Out:
#    Year  Rd  Pk   Tm         Player     Age Pos Born  \
# 0  2018   1   1  PHO  Deandre Ayton  19.338   C   bs
# 1  2018   1   2  SAC  Marvin Bagley  19.104   F   us
# 2  2018   1   4  MEM  Jaren Jackson  18.284   F   us
# 3  2018   1   5  DAL     Trae Young  19.280   G   us
# 4  2018   1   6  ORL  Mohamed Bamba  20.045   C   us
#
#                          College    From  ...  clast_true_shooting_percentage  \
# 0          University of Arizona  2019.0  ...                            0.65
# 1                Duke University  2019.0  ...                           0.643
# 2      Michigan State University  2019.0  ...                           0.647
# 3         University of Oklahoma  2019.0  ...                           0.585
# 4  University of Texas at Austin  2019.0  ...                           0.593
#
#    clast_turnover_percentage  clast_turnovers  clast_two_point_attempts  \
# 0                       11.3               69                       416
# 1                       12.2               75                       382
# 2                       17.4               62                       136
# 3                       18.2              167                       290
# 4                       12.3               46                       219
#
#    clast_two_point_percentage  clast_two_pointers  clast_usage_percentage  \
# 0                       0.635                 264                    26.6
# 1                       0.647                 247                    26.3
# 2                       0.596                  81                    23.5
# 3                       0.493                 143                    37.1
# 4                       0.603                 132                    21.3
#
#    clast_weight  clast_win_shares  clast_win_shares_per_40_minutes
# 0           250               7.6                            0.259
# 1           234               6.9                            0.248
# 2           242               4.6                            0.239
# 3           180               5.7                            0.201
# 4           225               4.8                            0.212
#
# [5 rows x 127 columns]

# %%
data.tail()
# Out:
#       Year  Rd   Pk   Tm          Player     Age Pos Born  \
# 1630  1980   5  103  DAL  Darrell Allums  21.277   F   us
# 1631  1980   7  141  GSW   Lorenzo Romar  21.215   G   us
# 1632  1980   8  168  POR   John Stroeder  21.327   F   us
# 1633  1980   8  169  DAL    Clarence Kea  21.134   F   us
# 1634  1980   9  182  GSW      Billy Reid  22.279   G   us
#
#                                     College    From  ...  \
# 1630  University of California, Los Angeles  1981.0  ...
# 1631               University of Washington  1981.0  ...
# 1632                  University of Montana  1988.0  ...
# 1633                       Lamar University  1981.0  ...
# 1634            University of San Francisco  1981.0  ...
#
#       clast_true_shooting_percentage  clast_turnover_percentage  \
# 1630                           0.509                        NaN
# 1631                           0.524                       14.2
# 1632                           0.528                       14.9
# 1633                           0.544                       13.6
# 1634                           0.609                        NaN
#
#       clast_turnovers  clast_two_point_attempts  clast_two_point_percentage  \
# 1630              NaN                       NaN                         NaN
# 1631             41.0                       NaN                         NaN
# 1632             44.0                       NaN                         NaN
# 1633             71.0                       NaN                         NaN
# 1634              NaN                       NaN                         NaN
#
#       clast_two_pointers  clast_usage_percentage  clast_weight  \
# 1630                 NaN                     NaN         220.0
# 1631                 NaN                     NaN         175.0
# 1632                 NaN                     NaN         260.0
# 1633                 NaN                     NaN         218.0
# 1634                 NaN                     NaN         190.0
#
#       clast_win_shares  clast_win_shares_per_40_minutes
# 1630               NaN                              NaN
# 1631               NaN                              NaN
# 1632               NaN                              NaN
# 1633               NaN                              NaN
# 1634               NaN                              NaN
#
# [5 rows x 127 columns]

# %%
for column in data.columns:
        print(column)
# Out:
# Year
# Rd
# Pk
# Tm
# Player
# Age
# Pos
# Born
# College
# From
# To
# G
# MP
# PTS
# TRB
# AST
# STL
# BLK
# FG%
# 2P%
# 3P%
# FT%
# WS
# WS/48
# college_code
# cfirst_assist_percentage
# cfirst_assists
# cfirst_block_percentage
# cfirst_blocks
# cfirst_box_plus_minus
# cfirst_conference
# cfirst_defensive_box_plus_minus
# cfirst_defensive_rebound_percentage
# cfirst_defensive_rebounds
# cfirst_defensive_win_shares
# cfirst_effective_field_goal_percentage
# cfirst_field_goal_attempts
# cfirst_field_goal_percentage
# cfirst_field_goals
# cfirst_free_throw_attempt_rate
# cfirst_free_throw_attempts
# cfirst_free_throw_percentage
# cfirst_free_throws
# cfirst_games_played
# cfirst_games_started
# cfirst_height
# cfirst_minutes_played
# cfirst_offensive_box_plus_minus
# cfirst_offensive_rebound_percentage
# cfirst_offensive_rebounds
# cfirst_offensive_win_shares
# cfirst_personal_fouls
# cfirst_player_efficiency_rating
# cfirst_player_id
# cfirst_points
# cfirst_points_produced
# cfirst_position
# cfirst_steal_percentage
# cfirst_steals
# cfirst_team_abbreviation
# cfirst_three_point_attempt_rate
# cfirst_three_point_attempts
# cfirst_three_point_percentage
# cfirst_three_pointers
# cfirst_total_rebound_percentage
# cfirst_total_rebounds
# cfirst_true_shooting_percentage
# cfirst_turnover_percentage
# cfirst_turnovers
# cfirst_two_point_attempts
# cfirst_two_point_percentage
# cfirst_two_pointers
# cfirst_usage_percentage
# cfirst_weight
# cfirst_win_shares
# cfirst_win_shares_per_40_minutes
# clast_assist_percentage
# clast_assists
# clast_block_percentage
# clast_blocks
# clast_box_plus_minus
# clast_conference
# clast_defensive_box_plus_minus
# clast_defensive_rebound_percentage
# clast_defensive_rebounds
# clast_defensive_win_shares
# clast_effective_field_goal_percentage
# clast_field_goal_attempts
# clast_field_goal_percentage
# clast_field_goals
# clast_free_throw_attempt_rate
# clast_free_throw_attempts
# clast_free_throw_percentage
# clast_free_throws
# clast_games_played
# clast_games_started
# clast_height
# clast_minutes_played
# clast_offensive_box_plus_minus
# clast_offensive_rebound_percentage
# clast_offensive_rebounds
# clast_offensive_win_shares
# clast_personal_fouls
# clast_player_efficiency_rating
# clast_player_id
# clast_points
# clast_points_produced
# clast_position
# clast_steal_percentage
# clast_steals
# clast_team_abbreviation
# clast_three_point_attempt_rate
# clast_three_point_attempts
# clast_three_point_percentage
# clast_three_pointers
# clast_total_rebound_percentage
# clast_total_rebounds
# clast_true_shooting_percentage
# clast_turnover_percentage
# clast_turnovers
# clast_two_point_attempts
# clast_two_point_percentage
# clast_two_pointers
# clast_usage_percentage
# clast_weight
# clast_win_shares
# clast_win_shares_per_40_minutes

# %%
data=pd.read_csv('raw_data.csv',index_col=False)
missing_players=data[data.clast_points.isnull()].Player
missing_players
# Out:
# 41             Ray Spalding
# 58                DJ Wilson
# 81           Damyean Dotson
# 119              AJ Hammons
# 152          Larry Nance Jr
# 153               RJ Hunter
# 163            Joseph Young
# 177               TJ Warren
# 186             PJ Hairston
# 187               CJ Wilcox
# 190            KJ McDaniels
# 193     Johnny O'Bryant III
# 196      Glenn Robinson III
# 217             CJ McCollum
# 242              Ricky Ledo
# 274             Jeff Taylor
# 313          MarShon Brooks
# 329        Andrew Goudelock
# 338          Wesley Johnson
# 396        Jeff Pendergraph
# 411                AJ Price
# 416                 OJ Mayo
# 421             DJ Augustin
# 431              JJ Hickson
# 438                DJ White
# 439              JR Giddens
# 444        Luc Mbah a Moute
# 449           Patrick Ewing
# 450             Bill Walker
# 490           DJ Strawberry
#                ...
# 1175             Greg Grant
# 1220          Nate Johnston
# 1230         Scottie Pippen
# 1252             Bob McCann
# 1261           Jamie Waller
# 1270          Ron Grandison
# 1271            Bart Kofoed
# 1295          Dennis Rodman
# 1342         Charles Oakley
# 1355               AC Green
# 1356           Terry Porter
# 1360             Manute Bol
# 1369         Gerald Wilkins
# 1386             Mario Elie
# 1423           Willie White
# 1425          Jerome Kersey
# 1428             David Pope
# 1436      Eddie Lee Wilkins
# 1437          Ken Bannister
# 1474            Mike Holton
# 1480         Sedale Threatt
# 1507            Dave Magley
# 1513            JJ Anderson
# 1517           Russ Schoene
# 1531           Eddie Hughes
# 1550            Kevin Loder
# 1584        Clinton Wheeler
# 1591           Mike O'Koren
# 1614            Rick Mahorn
# 1625            Mike Harper
# Name: Player, Length: 95, dtype: object

# %%
for i in missing_players.index:
    clear_output(wait=True)
    print(i)
    row=data.loc[i,:]
    lastname=row.Player
    if ' Jr.' in lastname:
        lastname=lastname.replace(' Jr.','')
    elif ' III' in lastname:
        lastname=lastname.replace(' III','')
    lastname=lastname.split(' ')[-1]
    
    try:
        for player in ncaa_roster(team=row.college_code,year=row.Year).players:
            if player.name:
                if lastname in player.name:
                    first=player.dataframe.iloc[0,:]
                    first.index=['cfirst_'+s for s in list(first.keys())]
                    data.loc[i,cfirst_columns]=first
                    last=player.dataframe.iloc[-2,:]
                    last.index=['clast_'+s for s in list(last.keys())]
                    data.loc[i,clast_columns]=last
                    break

    except:
        pass
missing_players=data[data.clast_points.isnull()].Player
missing_players
# Out:
# 1625
# 81         Damyean Dotson
# 152        Larry Nance Jr
# 186           PJ Hairston
# 242            Ricky Ledo
# 329      Andrew Goudelock
# 396      Jeff Pendergraph
# 578           Donta Smith
# 630          Qyntel Woods
# 642         Ronald Murray
# 652          Rodney White
# 654         Kedrick Brown
# 727          Andre Miller
# 740         Devean George
# 813         Johnny Taylor
# 829       Anthony Johnson
# 830       Stephen Jackson
# 859     Priest Lauderdale
# 863        Moochie Norris
# 934         Shawn Bradley
# 946      Gaylon Nickerson
# 981          Martin Lewis
# 1029             PJ Brown
# 1035         Tony Bennett
# 1074          Myron Brown
# 1075       Mike Iuzzolino
# 1081     Lamont Strothers
# 1082         Bobby Phills
# 1085          Greg Sutton
# 1121           AJ English
# 1130       Kenny Williams
# 1151           Shawn Kemp
# 1171        Scott Haffner
# 1175           Greg Grant
# 1220        Nate Johnston
# 1230       Scottie Pippen
# 1252           Bob McCann
# 1261         Jamie Waller
# 1271          Bart Kofoed
# 1295        Dennis Rodman
# 1342       Charles Oakley
# 1356         Terry Porter
# 1360           Manute Bol
# 1369       Gerald Wilkins
# 1386           Mario Elie
# 1423         Willie White
# 1425        Jerome Kersey
# 1428           David Pope
# 1436    Eddie Lee Wilkins
# 1437        Ken Bannister
# 1474          Mike Holton
# 1480       Sedale Threatt
# 1517         Russ Schoene
# 1531         Eddie Hughes
# 1550          Kevin Loder
# 1584      Clinton Wheeler
# 1591         Mike O'Koren
# 1614          Rick Mahorn
# 1625          Mike Harper
# Name: Player, dtype: object

# %%
data=data.drop(missing_players.index)

# %%
data.tail()
# Out:
#       Year  Rd  Pk   Tm           Player     Age  Pos Born  \
# 1502  1988   1  21  NJN   Eddie Phillips  20.278    F   us
# 1503  1988   1  23  BOS    Darren Tillis  22.132  C-F   us
# 1504  1988   2  24  SAS  Oliver Robinson  22.113    G   us
# 1505  1988   2  25  WSB    Bryan Warrick  22.348    G   us
# 1506  1988   2  27  MIL     Fred Roberts  21.324  F-C   us
#
#                                   College    From  ...  clast_total_rebounds  \
# 1502                University of Alabama  1983.0  ...                 258.0
# 1503           Cleveland State University  1983.0  ...                 346.0
# 1504  University of Alabama at Birmingham  1983.0  ...                 114.0
# 1505            Saint Joseph's University  1983.0  ...                  97.0
# 1506             Brigham Young University  1984.0  ...                 215.0
#
#       clast_true_shooting_percentage  clast_turnover_percentage  \
# 1502                           0.557                        NaN
# 1503                           0.538                        NaN
# 1504                           0.566                       10.2
# 1505                           0.553                        NaN
# 1506                           0.551                       20.5
#
#       clast_turnovers  clast_two_point_attempts  clast_two_point_percentage  \
# 1502              NaN                       NaN                         NaN
# 1503              NaN                       NaN                         NaN
# 1504             66.0                       NaN                         NaN
# 1505              NaN                       NaN                         NaN
# 1506            109.0                       NaN                         NaN
#
#       clast_two_pointers  clast_usage_percentage  clast_win_shares  \
# 1502                 NaN                     NaN               NaN
# 1503                 NaN                     NaN               NaN
# 1504                 NaN                     NaN               NaN
# 1505                 NaN                     NaN               NaN
# 1506                 NaN                     NaN               NaN
#
#       clast_win_shares_per_40_minutes
# 1502                              NaN
# 1503                              NaN
# 1504                              NaN
# 1505                              NaN
# 1506                              NaN
#
# [5 rows x 115 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1577 entries, 0 to 3053
# Columns: 127 entries, Year to clast_win_shares_per_40_minutes
# dtypes: float64(16), int32(3), object(108)
# memory usage: 1.5+ MB

# %%
data['Year']=draft_data.Year.astype(int)
data['cfirst_three_point_percentage']=data.cfirst_three_point_percentage.astype(int)
data[['Year','cfirst_three_point_percentage']].groupby(['Year']).mean()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-b81e3382c809> in <module>
#       1 data['Year']=draft_data.Year.astype(int)
# ----> 2 data['cfirst_three_point_percentage']=data.cfirst_three_point_percentage.astype(int)
#       3 data[['Year','cfirst_three_point_percentage']].groupby(['Year']).mean()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5689             # else, only a single dtype is given
#    5690             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 5691                                          **kwargs)
#    5692             return self._constructor(new_data).__finalize__(self)
#    5693
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, **kwargs)
#     529
#     530     def astype(self, dtype, **kwargs):
# --> 531         return self.apply('astype', dtype=dtype, **kwargs)
#     532
#     533     def convert(self, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#     393                                             copy=align_copy)
#     394
# --> 395             applied = getattr(b, f)(**kwargs)
#     396             result_blocks = _extend_blocks(applied, result_blocks)
#     397
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors, values, **kwargs)
#     532     def astype(self, dtype, copy=False, errors='raise', values=None, **kwargs):
#     533         return self._astype(dtype, copy=copy, errors=errors, values=values,
# --> 534                             **kwargs)
#     535
#     536     def _astype(self, dtype, copy=False, errors='raise', values=None,
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\blocks.py in _astype(self, dtype, copy, errors, values, **kwargs)
#     631
#     632                     # _astype_nansafe works fine with 1-d only
# --> 633                     values = astype_nansafe(values.ravel(), dtype, copy=True)
#     634
#     635                 # TODO(extension)
#
# ~\Anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     674
#     675         if not np.isfinite(arr).all():
# --> 676             raise ValueError('Cannot convert non-finite values (NA or inf) to '
#     677                              'integer')
#     678
#
# ValueError: Cannot convert non-finite values (NA or inf) to integer

# %%
data=data[data.Year>1987]
data.tail()
# Out:
#       Year  Rd  Pk   Tm            Player     Age  Pos Born  \
# 1221  1988   3  64  CLE   Winston Bennett  23.145    F   us
# 1222  1988   3  65  SEA      Corey Gaines  23.033    G   us
# 1223  1988   3  71  POR        Craig Neal  24.139    G   us
# 1224  1988   3  73  IND  Michael Anderson  22.103    G   us
# 1225  1988   3  74  BOS     Gerald Paddio  23.074  F-G   us
#
#                               College    From  ...  \
# 1221           University of Kentucky  1990.0  ...
# 1222      Loyola Marymount University  1989.0  ...
# 1223  Georgia Institute of Technology  1989.0  ...
# 1224                Drexel University  1989.0  ...
# 1225  University of Nevada, Las Vegas  1991.0  ...
#
#       clast_true_shooting_percentage  clast_turnover_percentage  \
# 1221                           0.556                       10.3
# 1222                           0.602                       21.9
# 1223                           0.598                       33.7
# 1224                           0.560                       19.6
# 1225                           0.599                       12.4
#
#       clast_turnovers  clast_two_point_attempts  clast_two_point_percentage  \
# 1221             52.0                     378.0                       0.513
# 1222            126.0                     280.0                       0.521
# 1223            105.0                      82.0                       0.585
# 1224            146.0                     387.0                       0.488
# 1225             78.0                     220.0                       0.505
#
#       clast_two_pointers  clast_usage_percentage  clast_weight  \
# 1221               194.0                     NaN         210.0
# 1222               146.0                     NaN         195.0
# 1223                48.0                     NaN         165.0
# 1224               189.0                     NaN         184.0
# 1225               111.0                     NaN         205.0
#
#       clast_win_shares  clast_win_shares_per_40_minutes
# 1221               NaN                              NaN
# 1222               NaN                              NaN
# 1223               NaN                              NaN
# 1224               NaN                              NaN
# 1225               NaN                              NaN
#
# [5 rows x 127 columns]

# %%
data=data.drop(columns=['clast_conference','clast_height','clast_player_id','clast_position','clast_team_abbreviation','clast_weight'])
data=data.drop(columns=['cfirst_conference','cfirst_height','cfirst_player_id','cfirst_position','cfirst_team_abbreviation','cfirst_weight'])

for s in ['clast_conference','clast_height','clast_player_id','clast_position','clast_team_abbreviation','clast_weight']:
    clast_columns.remove(s)
for s in ['cfirst_conference','cfirst_height','cfirst_player_id','cfirst_position','cfirst_team_abbreviation','cfirst_weight']:
    cfirst_columns.remove(s)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-109-9c60ae7d760a> in <module>
#       3
#       4 for s in ['clast_conference','clast_height','clast_player_id','clast_position','clast_team_abbreviation','clast_weight']:
# ----> 5     clast_columns.remove(s)
#       6 for s in ['cfirst_conference','cfirst_height','cfirst_player_id','cfirst_position','cfirst_team_abbreviation','cfirst_weight']:
#       7     cfirst_columns.remove(s)
#
# ValueError: list.remove(x): x not in list

# %%
data[clast_columns].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1192 entries, 0 to 1505
# Data columns (total 45 columns):
# clast_assist_percentage                  568 non-null object
# clast_assists                            1192 non-null object
# clast_block_percentage                   568 non-null object
# clast_blocks                             1192 non-null object
# clast_box_plus_minus                     330 non-null object
# clast_defensive_box_plus_minus           330 non-null object
# clast_defensive_rebound_percentage       368 non-null object
# clast_defensive_rebounds                 673 non-null object
# clast_defensive_win_shares               859 non-null object
# clast_effective_field_goal_percentage    1192 non-null object
# clast_field_goal_attempts                1192 non-null object
# clast_field_goal_percentage              1192 non-null object
# clast_field_goals                        1192 non-null object
# clast_free_throw_attempt_rate            1192 non-null object
# clast_free_throw_attempts                1192 non-null object
# clast_free_throw_percentage              1192 non-null object
# clast_free_throws                        1192 non-null object
# clast_games_played                       1192 non-null object
# clast_games_started                      891 non-null object
# clast_minutes_played                     1152 non-null object
# clast_offensive_box_plus_minus           330 non-null object
# clast_offensive_rebound_percentage       368 non-null object
# clast_offensive_rebounds                 673 non-null object
# clast_offensive_win_shares               859 non-null object
# clast_personal_fouls                     1149 non-null object
# clast_player_efficiency_rating           330 non-null object
# clast_points                             1192 non-null object
# clast_points_produced                    368 non-null object
# clast_steal_percentage                   371 non-null object
# clast_steals                             1192 non-null object
# clast_three_point_attempt_rate           1191 non-null object
# clast_three_point_attempts               1191 non-null object
# clast_three_point_percentage             1105 non-null object
# clast_three_pointers                     1192 non-null object
# clast_total_rebound_percentage           568 non-null object
# clast_total_rebounds                     1192 non-null object
# clast_true_shooting_percentage           1192 non-null object
# clast_turnover_percentage                1145 non-null object
# clast_turnovers                          1145 non-null object
# clast_two_point_attempts                 1191 non-null object
# clast_two_point_percentage               1191 non-null object
# clast_two_pointers                       1192 non-null object
# clast_usage_percentage                   568 non-null object
# clast_win_shares                         859 non-null object
# clast_win_shares_per_40_minutes          820 non-null object
# dtypes: object(45)
# memory usage: 428.4+ KB

# %% [markdown]
# Here's a list of clast columns with missing values (out of 1195 rows).
#
# |column                             |missing|
# |-----------------------------------|:-:|
# |three_point_attempt_rate           |1 |
# |three_point_attempts               |1 |
# |two_point_attempts                 |1 |
# |two_point_percentage               |1 |
# |minutes_played                     |40 |
# |personal_fouls                     |43 |
# |turnover_percentage                |47 |
# |turnovers                          |47 |
# |three_point_percentage             |87 |
# |games_started                      |302|
# |defensive_win_shares               |334|
# |offensive_win_shares               |334|
# |win_shares                         |334|
# |win_shares_per_40_minutes          |373|
# |defensive_rebounds                 |520|
# |offensive_rebounds                 |520|
# |assist_percentage                  |625|
# |block_percentage                   |625|
# |total_rebound_percentage           |625|
# |usage_percentage                   |625|
# |steal_percentage                   |822|
# |defensive_rebound_percentage       |825|
# |offensive_rebound_percentage       |825|
# |points_produced                    |825|
# |box_plus_minus                     |863|
# |defensive_box_plus_minus           |863|
# |offensive_box_plus_minus           |863|
# |player_efficiency_rating           |863|

# %% [markdown]
# #### 2pt/3pt Attempts

# %%
data[data.clast_three_point_attempts.isnull()]
# Out:
# Empty DataFrame
# Columns: [Year, Rd, Pk, Tm, Player, Age, Pos, Born, College, From, To, G, MP, PTS, TRB, AST, STL, BLK, FG%, 2P%, 3P%, FT%, WS, WS/48, college_code, cfirst_assist_percentage, cfirst_assists, cfirst_block_percentage, cfirst_blocks, cfirst_box_plus_minus, cfirst_conference, cfirst_defensive_box_plus_minus, cfirst_defensive_rebound_percentage, cfirst_defensive_rebounds, cfirst_defensive_win_shares, cfirst_effective_field_goal_percentage, cfirst_field_goal_attempts, cfirst_field_goal_percentage, cfirst_field_goals, cfirst_free_throw_attempt_rate, cfirst_free_throw_attempts, cfirst_free_throw_percentage, cfirst_free_throws, cfirst_games_played, cfirst_games_started, cfirst_height, cfirst_minutes_played, cfirst_offensive_box_plus_minus, cfirst_offensive_rebound_percentage, cfirst_offensive_rebounds, cfirst_offensive_win_shares, cfirst_personal_fouls, cfirst_player_efficiency_rating, cfirst_player_id, cfirst_points, cfirst_points_produced, cfirst_position, cfirst_steal_percentage, cfirst_steals, cfirst_team_abbreviation, cfirst_three_point_attempt_rate, cfirst_three_point_attempts, cfirst_three_point_percentage, cfirst_three_pointers, cfirst_total_rebound_percentage, cfirst_total_rebounds, cfirst_true_shooting_percentage, cfirst_turnover_percentage, cfirst_turnovers, cfirst_two_point_attempts, cfirst_two_point_percentage, cfirst_two_pointers, cfirst_usage_percentage, cfirst_weight, cfirst_win_shares, cfirst_win_shares_per_40_minutes, clast_assist_percentage, clast_assists, clast_block_percentage, clast_blocks, clast_box_plus_minus, clast_conference, clast_defensive_box_plus_minus, clast_defensive_rebound_percentage, clast_defensive_rebounds, clast_defensive_win_shares, clast_effective_field_goal_percentage, clast_field_goal_attempts, clast_field_goal_percentage, clast_field_goals, clast_free_throw_attempt_rate, clast_free_throw_attempts, clast_free_throw_percentage, clast_free_throws, clast_games_played, clast_games_started, clast_height, clast_minutes_played, clast_offensive_box_plus_minus, clast_offensive_rebound_percentage, ...]
# Index: []
#
# [0 rows x 127 columns]

# %%
data=data.drop(1055)

# %% [markdown]
# #### Minutes Played

# %%
data[data.clast_minutes_played.isnull()]

# %%
data.clast_minutes_played.hist()

# %%
import seaborn as sns

cols_w_missing=['minutes_played','personal_fouls','turnover_percentage','turnovers','three_point_percentage',
'games_started','defensive_win_shares','offensive_win_shares','win_shares','win_shares_per_40_minutes',
'defensive_rebounds','offensive_rebounds','assist_percentage','block_percentage','total_rebound_percentage','usage_percentage',
'steal_percentage','defensive_rebound_percentage','offensive_rebound_percentage','points_produced',
'box_plus_minus','defensive_box_plus_minus','offensive_box_plus_minus','player_efficiency_rating']
cl_missing=['clast_'+ s for s in cols_w_missing]

missing_map=sns.heatmap(data[cl_missing].isnull(), cbar=False)
missing_map.figure.savefig('missing_map.png')
missing_map

# %%
data[data.clast_three_point_percentage.isnull()][['Player','clast_three_pointers','clast_three_point_attempts']]
# Out:
#                    Player  clast_three_pointers  clast_three_point_attempts
# 55            Bam Adebayo                   0.0                         0.0
# 61            Harry Giles                   0.0                         0.0
# 67           Tony Bradley                   0.0                         0.0
# 98           Jakob Poeltl                   0.0                         0.0
# 108         Brice Johnson                   0.0                         0.0
# 112         Deyonta Davis                   0.0                         0.0
# 113         Cheick Diallo                   0.0                         0.0
# 132         Jahlil Okafor                   0.0                         0.0
# 133   Willie Cauley-Stein                   0.0                         0.0
# 213          Nerlens Noel                   0.0                         0.0
# 219          Steven Adams                   0.0                         0.0
# 224          Gorgui Dieng                   0.0                         0.0
# 225         Mason Plumlee                   0.0                         0.0
# 263           John Henson                   0.0                         0.0
# 265          Tyler Zeller                   0.0                         0.0
# 275         Bernard James                   0.0                         0.0
# 297      Tristan Thompson                   0.0                         0.0
# 311        Kenneth Faried                   0.0                         0.0
# 346              Ed Davis                   0.0                         0.0
# 378           Jordan Hill                   0.0                         0.0
# 392            Taj Gibson                   0.0                         0.0
# 401          DeJuan Blair                   0.0                         0.0
# 428     Marreese Speights                   0.0                         0.0
# 441           Joey Dorsey                   0.0                         0.0
# 443        DeAndre Jordan                   0.0                         0.0
# 460        Brandan Wright                   0.0                         0.0
# 469         Sean Williams                   0.0                         0.0
# 486            Aaron Gray                   0.0                         0.0
# 491     LaMarcus Aldridge                   0.0                         0.0
# 498      Patrick O'Bryant                   0.0                         0.0
# ...                   ...                   ...                         ...
# 914         Ervin Johnson                   0.0                         0.0
# 919         Luther Wright                   0.0                         0.0
# 948         Jim McIlvaine                   0.0                         0.0
# 960           Eric Mobley                   0.0                         0.0
# 968         Eric Montross                   0.0                         0.0
# 977              Don Reid                   0.0                         0.0
# 1001     Shaquille O'Neal                   0.0                         0.0
# 1028         Marlon Maxey                   0.0                         0.0
# 1042       Robert Werdann                   0.0                         0.0
# 1044            Matt Fish                   0.0                         0.0
# 1049      Dikembe Mutombo                   0.0                         0.0
# 1060        Anthony Avent                   0.0                         0.0
# 1062     Victor Alexander                   0.0                         0.0
# 1073         Donald Hodge                   0.0                         0.0
# 1091       Felton Spencer                   0.0                         0.0
# 1101          Terry Mills                   0.0                         0.0
# 1103       Duane Causwell                   0.0                         0.0
# 1110       Alaa Abdelnaby                   0.0                         0.0
# 1123      Steve Scheffler                   0.0                         0.0
# 1131         Derek Strong                   0.0                         0.0
# 1140          Stacey King                   0.0                         0.0
# 1164         Gary Leonard                   0.0                         0.0
# 1182            Tim Perry                   0.0                         0.0
# 1184         Rony Seikaly                   0.0                         0.0
# 1186          Will Perdue                   0.0                         0.0
# 1192         Eric Leckner                   0.0                         0.0
# 1202          Andrew Lang                   0.0                         0.0
# 1206  Charles Shackleford                   0.0                         0.0
# 1207           Grant Long                   0.0                         0.0
# 1209       Sylvester Gray                   0.0                         0.0
#
# [85 rows x 3 columns]

# %%
for i in list(data[data.clast_three_point_percentage.isnull()].index):
    data.loc[i,'clast_three_point_percentage']=0

# %%
data[data.clast_three_point_percentage.isnull()]
# Out:
# Empty DataFrame
# Columns: [Year, Rd, Pk, Tm, Player, Age, Pos, Born, College, From, To, G, MP, PTS, TRB, AST, STL, BLK, FG%, 2P%, 3P%, FT%, WS, WS/48, college_code, cfirst_assist_percentage, cfirst_assists, cfirst_block_percentage, cfirst_blocks, cfirst_box_plus_minus, cfirst_conference, cfirst_defensive_box_plus_minus, cfirst_defensive_rebound_percentage, cfirst_defensive_rebounds, cfirst_defensive_win_shares, cfirst_effective_field_goal_percentage, cfirst_field_goal_attempts, cfirst_field_goal_percentage, cfirst_field_goals, cfirst_free_throw_attempt_rate, cfirst_free_throw_attempts, cfirst_free_throw_percentage, cfirst_free_throws, cfirst_games_played, cfirst_games_started, cfirst_height, cfirst_minutes_played, cfirst_offensive_box_plus_minus, cfirst_offensive_rebound_percentage, cfirst_offensive_rebounds, cfirst_offensive_win_shares, cfirst_personal_fouls, cfirst_player_efficiency_rating, cfirst_player_id, cfirst_points, cfirst_points_produced, cfirst_position, cfirst_steal_percentage, cfirst_steals, cfirst_team_abbreviation, cfirst_three_point_attempt_rate, cfirst_three_point_attempts, cfirst_three_point_percentage, cfirst_three_pointers, cfirst_total_rebound_percentage, cfirst_total_rebounds, cfirst_true_shooting_percentage, cfirst_turnover_percentage, cfirst_turnovers, cfirst_two_point_attempts, cfirst_two_point_percentage, cfirst_two_pointers, cfirst_usage_percentage, cfirst_weight, cfirst_win_shares, cfirst_win_shares_per_40_minutes, clast_assist_percentage, clast_assists, clast_block_percentage, clast_blocks, clast_box_plus_minus, clast_conference, clast_defensive_box_plus_minus, clast_defensive_rebound_percentage, clast_defensive_rebounds, clast_defensive_win_shares, clast_effective_field_goal_percentage, clast_field_goal_attempts, clast_field_goal_percentage, clast_field_goals, clast_free_throw_attempt_rate, clast_free_throw_attempts, clast_free_throw_percentage, clast_free_throws, clast_games_played, clast_games_started, clast_height, clast_minutes_played, clast_offensive_box_plus_minus, clast_offensive_rebound_percentage, ...]
# Index: []
#
# [0 rows x 127 columns]

# %%
data[data.clast_minutes_played.isnull()][clast_columns]
# Out:
#       clast_assist_percentage  clast_assists  clast_block_percentage  \
# 737                       NaN           86.0                     NaN
# 757                       NaN           30.0                     NaN
# 758                       NaN           74.0                     NaN
# 759                       NaN           88.0                     NaN
# 760                       NaN          134.0                     NaN
# 761                       NaN           77.0                     NaN
# 763                       NaN           95.0                     NaN
# 764                       NaN           17.0                     NaN
# 765                       NaN           19.0                     NaN
# 767                       NaN           82.0                     NaN
# 768                       NaN          155.0                     NaN
# 769                       NaN           66.0                     NaN
# 770                       NaN           49.0                     NaN
# 771                       NaN           74.0                     NaN
# 772                       NaN           15.0                     NaN
# 773                       NaN          152.0                     NaN
# 774                       NaN           85.0                     NaN
# 775                       NaN           57.0                     NaN
# 776                       NaN           56.0                     NaN
# 777                       NaN           28.0                     NaN
# 778                       NaN           80.0                     NaN
# 779                       NaN           41.0                     NaN
# 780                       NaN          161.0                     NaN
# 781                       NaN           30.0                     NaN
# 782                       NaN          240.0                     NaN
# 783                       NaN           88.0                     NaN
# 785                       NaN            2.0                     NaN
# 786                       NaN           19.0                     NaN
# 787                       NaN          135.0                     NaN
# 788                       NaN           46.0                     NaN
# 789                       NaN          205.0                     NaN
# 790                       NaN           32.0                     NaN
# 791                       NaN           69.0                     NaN
# 792                       NaN           67.0                     NaN
# 793                       NaN           83.0                     NaN
# 794                       NaN           31.0                     NaN
# 795                       NaN           48.0                     NaN
# 797                       NaN           35.0                     NaN
# 1108                      NaN           95.0                     NaN
#
#       clast_blocks  clast_box_plus_minus  clast_defensive_box_plus_minus  \
# 737            8.0                   NaN                             NaN
# 757           30.0                   NaN                             NaN
# 758           36.0                   NaN                             NaN
# 759           46.0                   NaN                             NaN
# 760            4.0                   NaN                             NaN
# 761           13.0                   NaN                             NaN
# 763           20.0                   NaN                             NaN
# 764           33.0                   NaN                             NaN
# 765           26.0                   NaN                             NaN
# 767            7.0                   NaN                             NaN
# 768            2.0                   NaN                             NaN
# 769           16.0                   NaN                             NaN
# 770           26.0                   NaN                             NaN
# 771           10.0                   NaN                             NaN
# 772           98.0                   NaN                             NaN
# 773            3.0                   NaN                             NaN
# 774           24.0                   NaN                             NaN
# 775            6.0                   NaN                             NaN
# 776           17.0                   NaN                             NaN
# 777           75.0                   NaN                             NaN
# 778           26.0                   NaN                             NaN
# 779           12.0                   NaN                             NaN
# 780            2.0                   NaN                             NaN
# 781          125.0                   NaN                             NaN
# 782           12.0                   NaN                             NaN
# 783           18.0                   NaN                             NaN
# 785           26.0                   NaN                             NaN
# 786           24.0                   NaN                             NaN
# 787           23.0                   NaN                             NaN
# 788           30.0                   NaN                             NaN
# 789            2.0                   NaN                             NaN
# 790           55.0                   NaN                             NaN
# 791            8.0                   NaN                             NaN
# 792           25.0                   NaN                             NaN
# 793           10.0                   NaN                             NaN
# 794            9.0                   NaN                             NaN
# 795           41.0                   NaN                             NaN
# 797           33.0                   NaN                             NaN
# 1108          12.0                   NaN                             NaN
#
#       clast_defensive_rebound_percentage  clast_defensive_rebounds  \
# 737                                  NaN                       NaN
# 757                                  NaN                       NaN
# 758                                  NaN                       NaN
# 759                                  NaN                       NaN
# 760                                  NaN                       NaN
# 761                                  NaN                       NaN
# 763                                  NaN                       NaN
# 764                                  NaN                       NaN
# 765                                  NaN                       NaN
# 767                                  NaN                       NaN
# 768                                  NaN                       NaN
# 769                                  NaN                       NaN
# 770                                  NaN                       NaN
# 771                                  NaN                       NaN
# 772                                  NaN                       NaN
# 773                                  NaN                       NaN
# 774                                  NaN                       NaN
# 775                                  NaN                       NaN
# 776                                  NaN                       NaN
# 777                                  NaN                       NaN
# 778                                  NaN                       NaN
# 779                                  NaN                       NaN
# 780                                  NaN                       NaN
# 781                                  NaN                       NaN
# 782                                  NaN                       NaN
# 783                                  NaN                       NaN
# 785                                  NaN                       NaN
# 786                                  NaN                       NaN
# 787                                  NaN                       NaN
# 788                                  NaN                       NaN
# 789                                  NaN                       NaN
# 790                                  NaN                       NaN
# 791                                  NaN                       NaN
# 792                                  NaN                       NaN
# 793                                  NaN                       NaN
# 794                                  NaN                       NaN
# 795                                  NaN                       NaN
# 797                                  NaN                       NaN
# 1108                                 NaN                       NaN
#
#       clast_defensive_win_shares  clast_effective_field_goal_percentage  ...  \
# 737                          1.7                                  0.486  ...
# 757                          3.0                                  0.584  ...
# 758                          2.6                                  0.649  ...
# 759                          2.7                                  0.579  ...
# 760                          0.7                                  0.547  ...
# 761                          2.5                                  0.454  ...
# 763                          3.5                                  0.544  ...
# 764                          2.6                                  0.507  ...
# 765                          1.0                                  0.567  ...
# 767                          1.9                                  0.508  ...
# 768                          1.3                                  0.552  ...
# 769                          1.0                                  0.526  ...
# 770                          3.4                                  0.549  ...
# 771                          1.5                                  0.504  ...
# 772                          2.8                                  0.553  ...
# 773                          1.7                                  0.510  ...
# 774                          2.2                                  0.494  ...
# 775                          1.3                                  0.473  ...
# 776                          1.3                                  0.582  ...
# 777                          3.4                                  0.597  ...
# 778                          2.9                                  0.482  ...
# 779                          1.7                                  0.511  ...
# 780                          1.6                                  0.589  ...
# 781                          2.8                                  0.500  ...
# 782                          1.7                                  0.508  ...
# 783                          1.7                                  0.566  ...
# 785                          2.0                                  0.634  ...
# 786                          1.8                                  0.483  ...
# 787                          1.0                                  0.494  ...
# 788                          0.8                                  0.511  ...
# 789                          1.3                                  0.508  ...
# 790                          2.2                                  0.533  ...
# 791                          0.4                                  0.491  ...
# 792                          1.6                                  0.570  ...
# 793                          1.9                                  0.562  ...
# 794                          2.3                                  0.500  ...
# 795                          3.3                                  0.618  ...
# 797                          1.7                                  0.597  ...
# 1108                         NaN                                  0.504  ...
#
#       clast_total_rebounds  clast_true_shooting_percentage  \
# 737                  166.0                           0.514
# 757                  389.0                           0.607
# 758                  195.0                           0.659
# 759                  344.0                           0.595
# 760                   59.0                           0.589
# 761                  162.0                           0.505
# 763                  184.0                           0.573
# 764                  228.0                           0.586
# 765                   30.0                           0.590
# 767                  302.0                           0.567
# 768                  130.0                           0.585
# 769                  225.0                           0.574
# 770                  201.0                           0.580
# 771                  148.0                           0.537
# 772                  265.0                           0.569
# 773                  137.0                           0.550
# 774                  152.0                           0.509
# 775                  165.0                           0.508
# 776                  125.0                           0.608
# 777                  282.0                           0.612
# 778                  221.0                           0.540
# 779                  119.0                           0.536
# 780                  123.0                           0.640
# 781                  282.0                           0.516
# 782                   71.0                           0.535
# 783                  147.0                           0.617
# 785                  109.0                           0.596
# 786                  197.0                           0.525
# 787                  195.0                           0.537
# 788                  187.0                           0.559
# 789                   89.0                           0.527
# 790                  186.0                           0.570
# 791                  131.0                           0.548
# 792                  195.0                           0.595
# 793                  130.0                           0.587
# 794                  359.0                           0.536
# 795                  271.0                           0.641
# 797                  223.0                           0.624
# 1108                 456.0                           0.540
#
#       clast_turnover_percentage  clast_turnovers  clast_two_point_attempts  \
# 737                         NaN              NaN                     337.0
# 757                         NaN              NaN                     531.0
# 758                         NaN              NaN                     272.0
# 759                         NaN              NaN                     386.0
# 760                         NaN              NaN                     120.0
# 761                         NaN              NaN                     395.0
# 763                         NaN              NaN                     344.0
# 764                         NaN              NaN                     306.0
# 765                         NaN              NaN                      96.0
# 767                         NaN              NaN                     336.0
# 768                         NaN              NaN                     245.0
# 769                         NaN              NaN                     337.0
# 770                         NaN              NaN                     290.0
# 771                         NaN              NaN                     280.0
# 772                         NaN              NaN                     347.0
# 773                         NaN              NaN                     338.0
# 774                         NaN              NaN                     300.0
# 775                         NaN              NaN                     357.0
# 776                         NaN              NaN                     244.0
# 777                         NaN              NaN                     318.0
# 778                         NaN              NaN                     337.0
# 779                         NaN              NaN                     164.0
# 780                         NaN              NaN                     213.0
# 781                         NaN              NaN                     416.0
# 782                         NaN              NaN                     113.0
# 783                         NaN              NaN                     236.0
# 785                         NaN              NaN                      82.0
# 786                         NaN              NaN                     190.0
# 787                         NaN              NaN                     320.0
# 788                         NaN              NaN                     271.0
# 789                         NaN              NaN                     179.0
# 790                         NaN              NaN                     168.0
# 791                         NaN              NaN                     296.0
# 792                         NaN              NaN                     261.0
# 793                         NaN              NaN                     322.0
# 794                         NaN              NaN                     291.0
# 795                         NaN              NaN                     257.0
# 797                         NaN              NaN                     216.0
# 1108                       13.2             92.0                     496.0
#
#       clast_two_point_percentage  clast_two_pointers  clast_usage_percentage  \
# 737                        0.525               177.0                     NaN
# 757                        0.584               310.0                     NaN
# 758                        0.662               180.0                     NaN
# 759                        0.580               224.0                     NaN
# 760                        0.483                58.0                     NaN
# 761                        0.461               182.0                     NaN
# 763                        0.538               185.0                     NaN
# 764                        0.497               152.0                     NaN
# 765                        0.552                53.0                     NaN
# 767                        0.530               178.0                     NaN
# 768                        0.465               114.0                     NaN
# 769                        0.516               174.0                     NaN
# 770                        0.524               152.0                     NaN
# 771                        0.518               145.0                     NaN
# 772                        0.553               192.0                     NaN
# 773                        0.479               162.0                     NaN
# 774                        0.487               146.0                     NaN
# 775                        0.468               167.0                     NaN
# 776                        0.639               156.0                     NaN
# 777                        0.597               190.0                     NaN
# 778                        0.475               160.0                     NaN
# 779                        0.555                91.0                     NaN
# 780                        0.577               123.0                     NaN
# 781                        0.500               208.0                     NaN
# 782                        0.513                58.0                     NaN
# 783                        0.525               124.0                     NaN
# 785                        0.634                52.0                     NaN
# 786                        0.495                94.0                     NaN
# 787                        0.497               159.0                     NaN
# 788                        0.524               142.0                     NaN
# 789                        0.458                82.0                     NaN
# 790                        0.548                92.0                     NaN
# 791                        0.480               142.0                     NaN
# 792                        0.548               143.0                     NaN
# 793                        0.575               185.0                     NaN
# 794                        0.533               155.0                     NaN
# 795                        0.607               156.0                     NaN
# 797                        0.597               129.0                     NaN
# 1108                       0.504               250.0                     NaN
#
#       clast_win_shares  clast_win_shares_per_40_minutes
# 737                3.4                              NaN
# 757                8.3                              NaN
# 758                7.4                              NaN
# 759                6.1                              NaN
# 760                2.8                              NaN
# 761                4.3                              NaN
# 763                7.1                              NaN
# 764                6.0                              NaN
# 765                2.0                              NaN
# 767                5.4                              NaN
# 768                5.1                              NaN
# 769                4.5                              NaN
# 770                6.4                              NaN
# 771                3.3                              NaN
# 772                5.4                              NaN
# 773                4.9                              NaN
# 774                3.7                              NaN
# 775                2.9                              NaN
# 776                4.7                              NaN
# 777                6.5                              NaN
# 778                5.1                              NaN
# 779                3.0                              NaN
# 780                6.6                              NaN
# 781                4.4                              NaN
# 782                3.1                              NaN
# 783                5.7                              NaN
# 785                2.8                              NaN
# 786                2.7                              NaN
# 787                3.1                              NaN
# 788                2.7                              NaN
# 789                3.2                              NaN
# 790                3.8                              NaN
# 791                3.0                              NaN
# 792                5.1                              NaN
# 793                5.1                              NaN
# 794                3.8                              NaN
# 795                6.7                              NaN
# 797                4.5                              NaN
# 1108               NaN                              NaN
#
# [39 rows x 45 columns]

# %%
data=data.drop(list(data[data.clast_minutes_played.isnull()].index))

# %%
data[data.clast_minutes_played.isnull()]
# Out:
# Empty DataFrame
# Columns: [Year, Rd, Pk, Tm, Player, Age, Pos, Born, College, From, To, G, MP, PTS, TRB, AST, STL, BLK, FG%, 2P%, 3P%, FT%, WS, WS/48, college_code, cfirst_assist_percentage, cfirst_assists, cfirst_block_percentage, cfirst_blocks, cfirst_box_plus_minus, cfirst_conference, cfirst_defensive_box_plus_minus, cfirst_defensive_rebound_percentage, cfirst_defensive_rebounds, cfirst_defensive_win_shares, cfirst_effective_field_goal_percentage, cfirst_field_goal_attempts, cfirst_field_goal_percentage, cfirst_field_goals, cfirst_free_throw_attempt_rate, cfirst_free_throw_attempts, cfirst_free_throw_percentage, cfirst_free_throws, cfirst_games_played, cfirst_games_started, cfirst_height, cfirst_minutes_played, cfirst_offensive_box_plus_minus, cfirst_offensive_rebound_percentage, cfirst_offensive_rebounds, cfirst_offensive_win_shares, cfirst_personal_fouls, cfirst_player_efficiency_rating, cfirst_player_id, cfirst_points, cfirst_points_produced, cfirst_position, cfirst_steal_percentage, cfirst_steals, cfirst_team_abbreviation, cfirst_three_point_attempt_rate, cfirst_three_point_attempts, cfirst_three_point_percentage, cfirst_three_pointers, cfirst_total_rebound_percentage, cfirst_total_rebounds, cfirst_true_shooting_percentage, cfirst_turnover_percentage, cfirst_turnovers, cfirst_two_point_attempts, cfirst_two_point_percentage, cfirst_two_pointers, cfirst_usage_percentage, cfirst_weight, cfirst_win_shares, cfirst_win_shares_per_40_minutes, clast_assist_percentage, clast_assists, clast_block_percentage, clast_blocks, clast_box_plus_minus, clast_conference, clast_defensive_box_plus_minus, clast_defensive_rebound_percentage, clast_defensive_rebounds, clast_defensive_win_shares, clast_effective_field_goal_percentage, clast_field_goal_attempts, clast_field_goal_percentage, clast_field_goals, clast_free_throw_attempt_rate, clast_free_throw_attempts, clast_free_throw_percentage, clast_free_throws, clast_games_played, clast_games_started, clast_height, clast_minutes_played, clast_offensive_box_plus_minus, clast_offensive_rebound_percentage, ...]
# Index: []
#
# [0 rows x 127 columns]

# %%
missing_map=sns.heatmap(data[cl_missing].isnull(), cbar=False)

# %%
data[data.clast_personal_fouls.isnull()][['Player']+clast_columns]
# Out:
# Empty DataFrame
# Columns: [Player, clast_assist_percentage, clast_assists, clast_block_percentage, clast_blocks, clast_box_plus_minus, clast_defensive_box_plus_minus, clast_defensive_rebound_percentage, clast_defensive_rebounds, clast_defensive_win_shares, clast_effective_field_goal_percentage, clast_field_goal_attempts, clast_field_goal_percentage, clast_field_goals, clast_free_throw_attempt_rate, clast_free_throw_attempts, clast_free_throw_percentage, clast_free_throws, clast_games_played, clast_games_started, clast_minutes_played, clast_offensive_box_plus_minus, clast_offensive_rebound_percentage, clast_offensive_rebounds, clast_offensive_win_shares, clast_personal_fouls, clast_player_efficiency_rating, clast_points, clast_points_produced, clast_steal_percentage, clast_steals, clast_three_point_attempt_rate, clast_three_point_attempts, clast_three_point_percentage, clast_three_pointers, clast_total_rebound_percentage, clast_total_rebounds, clast_true_shooting_percentage, clast_turnover_percentage, clast_turnovers, clast_two_point_attempts, clast_two_point_percentage, clast_two_pointers, clast_usage_percentage, clast_win_shares, clast_win_shares_per_40_minutes]
# Index: []
#
# [0 rows x 46 columns]

# %%
for i in list(data[data.clast_turnovers.isnull()].index):
    data.loc[i,'clast_turnovers']=0
    data.loc[i,'clast_turnover_percentage']=0

# %%
for i in list(data[data.clast_personal_fouls.isnull()].index):
    data.loc[i,'clast_personal_fouls']=0

# %%
cf_missing=['cfirst_'+ s.replace('clast_','') for s in cl_missing]

cf_missing
# Out:
# ['cfirst_minutes_played',
#  'cfirst_personal_fouls',
#  'cfirst_turnover_percentage',
#  'cfirst_turnovers',
#  'cfirst_three_point_percentage',
#  'cfirst_games_started',
#  'cfirst_defensive_win_shares',
#  'cfirst_offensive_win_shares',
#  'cfirst_win_shares',
#  'cfirst_win_shares_per_40_minutes',
#  'cfirst_defensive_rebounds',
#  'cfirst_offensive_rebounds',
#  'cfirst_assist_percentage',
#  'cfirst_block_percentage',
#  'cfirst_total_rebound_percentage',
#  'cfirst_usage_percentage',
#  'cfirst_steal_percentage',
#  'cfirst_defensive_rebound_percentage',
#  'cfirst_offensive_rebound_percentage',
#  'cfirst_points_produced',
#  'cfirst_box_plus_minus',
#  'cfirst_defensive_box_plus_minus',
#  'cfirst_offensive_box_plus_minus',
#  'cfirst_player_efficiency_rating']

# %%
missing_map=sns.heatmap(data[cf_missing].isnull(), cbar=False)

# %%
fill=['cfirst_minutes_played','cfirst_personal_fouls','cfirst_turnover_percentage','cfirst_turnovers','cfirst_three_point_percentage']
for col in fill:
    for i in list(data[data[col].isnull()].index):
        data.loc[i,col]=0

# %%
missing_map=sns.heatmap(data[cf_missing].isnull(), cbar=False)

# %%
data.dtypes
# Out:
# Year                                    int64
# Rd                                      int64
# Pk                                      int64
# Tm                                     object
# Player                                 object
# Age                                   float64
# Pos                                    object
# Born                                   object
# College                                object
# From                                  float64
# To                                    float64
# G                                     float64
# MP                                    float64
# PTS                                   float64
# TRB                                   float64
# AST                                   float64
# STL                                   float64
# BLK                                   float64
# FG%                                   float64
# 2P%                                   float64
# 3P%                                   float64
# FT%                                   float64
# WS                                    float64
# WS/48                                 float64
# college_code                           object
# cfirst_assist_percentage              float64
# cfirst_assists                        float64
# cfirst_block_percentage               float64
# cfirst_blocks                         float64
# cfirst_box_plus_minus                 float64
#                                        ...
# clast_free_throw_percentage           float64
# clast_free_throws                     float64
# clast_games_played                    float64
# clast_games_started                   float64
# clast_minutes_played                  float64
# clast_offensive_box_plus_minus        float64
# clast_offensive_rebound_percentage    float64
# clast_offensive_rebounds              float64
# clast_offensive_win_shares            float64
# clast_personal_fouls                  float64
# clast_player_efficiency_rating        float64
# clast_points                          float64
# clast_points_produced                 float64
# clast_steal_percentage                float64
# clast_steals                          float64
# clast_three_point_attempt_rate        float64
# clast_three_point_attempts            float64
# clast_three_point_percentage          float64
# clast_three_pointers                  float64
# clast_total_rebound_percentage        float64
# clast_total_rebounds                  float64
# clast_true_shooting_percentage        float64
# clast_turnover_percentage             float64
# clast_turnovers                       float64
# clast_two_point_attempts              float64
# clast_two_point_percentage            float64
# clast_two_pointers                    float64
# clast_usage_percentage                float64
# clast_win_shares                      float64
# clast_win_shares_per_40_minutes       float64
# Length: 115, dtype: object

# %%
data.to_csv('player_data.csv',index=False,header=True)

# %%
test1=data.head()
test2=data.tail()

# %%
test1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 0 to 4
# Columns: 115 entries, Year to clast_win_shares_per_40_minutes
# dtypes: float64(106), int64(3), object(6)
# memory usage: 4.5+ KB

# %%
row=test1.loc[0,:]
row
# Out:
# Year                                                   2018
# Rd                                                        1
# Pk                                                        1
# Tm                                                      PHO
# Player                                        Deandre Ayton
# Age                                                  19.338
# Pos                                                       C
# Born                                                     bs
# College                               University of Arizona
# From                                                   2019
# To                                                     2019
# G                                                        71
# MP                                                     30.7
# PTS                                                    16.3
# TRB                                                    10.3
# AST                                                     1.8
# STL                                                     0.9
# BLK                                                     0.9
# FG%                                                   0.585
# 2P%                                                   0.588
# 3P%                                                       0
# FT%                                                   0.746
# WS                                                      5.8
# WS/48                                                 0.128
# college_code                                        ARIZONA
# cfirst_assist_percentage                               10.2
# cfirst_assists                                           57
# cfirst_block_percentage                                 6.1
# cfirst_blocks                                            66
# cfirst_box_plus_minus                                  10.9
#                                               ...
# clast_free_throw_percentage                           0.733
# clast_free_throws                                       140
# clast_games_played                                       35
# clast_games_started                                      35
# clast_minutes_played                                   1172
# clast_offensive_box_plus_minus                          6.8
# clast_offensive_rebound_percentage                     13.5
# clast_offensive_rebounds                                118
# clast_offensive_win_shares                              5.5
# clast_personal_fouls                                     81
# clast_player_efficiency_rating                         32.6
# clast_points                                            704
# clast_points_produced                                   666
# clast_steal_percentage                                    1
# clast_steals                                             20
# clast_three_point_attempt_rate                        0.078
# clast_three_point_attempts                               35
# clast_three_point_percentage                          0.343
# clast_three_pointers                                     12
# clast_total_rebound_percentage                         21.4
# clast_total_rebounds                                    405
# clast_true_shooting_percentage                         0.65
# clast_turnover_percentage                              11.3
# clast_turnovers                                          69
# clast_two_point_attempts                                416
# clast_two_point_percentage                            0.635
# clast_two_pointers                                      264
# clast_usage_percentage                                 26.6
# clast_win_shares                                        7.6
# clast_win_shares_per_40_minutes                       0.259
# Name: 0, Length: 115, dtype: object

# %%
t=ncaa_teams(year=row.Year).__call__(row.college_code).dataframe

# %%
t.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, ARIZONA to ARIZONA
# Data columns (total 84 columns):
# abbreviation                              1 non-null object
# assist_percentage                         1 non-null float64
# assists                                   1 non-null int64
# away_losses                               1 non-null int64
# away_wins                                 1 non-null int64
# block_percentage                          1 non-null float64
# blocks                                    1 non-null int64
# conference                                1 non-null object
# conference_losses                         1 non-null int64
# conference_wins                           1 non-null int64
# defensive_rebounds                        1 non-null int64
# effective_field_goal_percentage           1 non-null float64
# field_goal_attempts                       1 non-null int64
# field_goal_percentage                     1 non-null float64
# field_goals                               1 non-null int64
# free_throw_attempt_rate                   1 non-null float64
# free_throw_attempts                       1 non-null int64
# free_throw_percentage                     1 non-null float64
# free_throws                               1 non-null int64
# free_throws_per_field_goal_attempt        1 non-null float64
# games_played                              1 non-null int64
# home_losses                               1 non-null int64
# home_wins                                 1 non-null int64
# losses                                    1 non-null int64
# minutes_played                            1 non-null int64
# name                                      1 non-null object
# net_rating                                1 non-null float64
# offensive_rating                          1 non-null float64
# offensive_rebound_percentage              1 non-null float64
# offensive_rebounds                        1 non-null int64
# opp_assist_percentage                     1 non-null float64
# opp_assists                               1 non-null int64
# opp_block_percentage                      1 non-null float64
# opp_blocks                                1 non-null int64
# opp_defensive_rebounds                    1 non-null int64
# opp_effective_field_goal_percentage       1 non-null float64
# opp_field_goal_attempts                   1 non-null int64
# opp_field_goal_percentage                 1 non-null float64
# opp_field_goals                           1 non-null int64
# opp_free_throw_attempt_rate               1 non-null float64
# opp_free_throw_attempts                   1 non-null int64
# opp_free_throw_percentage                 1 non-null float64
# opp_free_throws                           1 non-null int64
# opp_free_throws_per_field_goal_attempt    1 non-null float64
# opp_offensive_rating                      1 non-null float64
# opp_offensive_rebound_percentage          1 non-null float64
# opp_offensive_rebounds                    1 non-null int64
# opp_personal_fouls                        1 non-null int64
# opp_points                                1 non-null int64
# opp_steal_percentage                      1 non-null float64
# opp_steals                                1 non-null int64
# opp_three_point_attempt_rate              1 non-null float64
# opp_three_point_field_goal_attempts       1 non-null int64
# opp_three_point_field_goal_percentage     1 non-null float64
# opp_three_point_field_goals               1 non-null int64
# opp_total_rebound_percentage              1 non-null float64
# opp_total_rebounds                        1 non-null int64
# opp_true_shooting_percentage              1 non-null float64
# opp_turnover_percentage                   1 non-null float64
# opp_turnovers                             1 non-null int64
# opp_two_point_field_goal_attempts         1 non-null int64
# opp_two_point_field_goal_percentage       1 non-null float64
# opp_two_point_field_goals                 1 non-null int64
# pace                                      1 non-null float64
# personal_fouls                            1 non-null int64
# points                                    1 non-null int64
# simple_rating_system                      1 non-null float64
# steal_percentage                          1 non-null float64
# steals                                    1 non-null int64
# strength_of_schedule                      1 non-null float64
# three_point_attempt_rate                  1 non-null float64
# three_point_field_goal_attempts           1 non-null int64
# three_point_field_goal_percentage         1 non-null float64
# three_point_field_goals                   1 non-null int64
# total_rebound_percentage                  1 non-null float64
# total_rebounds                            1 non-null int64
# true_shooting_percentage                  1 non-null float64
# turnover_percentage                       1 non-null float64
# turnovers                                 1 non-null int64
# two_point_field_goal_attempts             1 non-null int64
# two_point_field_goal_percentage           1 non-null float64
# two_point_field_goals                     1 non-null int64
# win_percentage                            1 non-null float64
# wins                                      1 non-null int64
# dtypes: float64(37), int64(44), object(3)
# memory usage: 680.0+ bytes

# %%
data=pd.read_csv('player_data.csv',index_col=None)
data.head()
# Out:
#    Year  Rd  Pk   Tm         Player     Age Pos Born  \
# 0  2018   1   1  PHO  Deandre Ayton  19.338   C   bs
# 1  2018   1   2  SAC  Marvin Bagley  19.104   F   us
# 2  2018   1   4  MEM  Jaren Jackson  18.284   F   us
# 3  2018   1   5  DAL     Trae Young  19.280   G   us
# 4  2018   1   6  ORL  Mohamed Bamba  20.045   C   us
#
#                          College    From  ...  clast_total_rebounds  \
# 0          University of Arizona  2019.0  ...                 405.0
# 1                Duke University  2019.0  ...                 366.0
# 2      Michigan State University  2019.0  ...                 203.0
# 3         University of Oklahoma  2019.0  ...                 125.0
# 4  University of Texas at Austin  2019.0  ...                 316.0
#
#    clast_true_shooting_percentage  clast_turnover_percentage  clast_turnovers  \
# 0                           0.650                       11.3             69.0
# 1                           0.643                       12.2             75.0
# 2                           0.647                       17.4             62.0
# 3                           0.585                       18.2            167.0
# 4                           0.593                       12.3             46.0
#
#    clast_two_point_attempts  clast_two_point_percentage  clast_two_pointers  \
# 0                     416.0                       0.635               264.0
# 1                     382.0                       0.647               247.0
# 2                     136.0                       0.596                81.0
# 3                     290.0                       0.493               143.0
# 4                     219.0                       0.603               132.0
#
#    clast_usage_percentage  clast_win_shares  clast_win_shares_per_40_minutes
# 0                    26.6               7.6                            0.259
# 1                    26.3               6.9                            0.248
# 2                    23.5               4.6                            0.239
# 3                    37.1               5.7                            0.201
# 4                    21.3               4.8                            0.212
#
# [5 rows x 115 columns]

# %%
team_columns=['assist_percentage',                        
'assists',                                   
'away_losses',                              
'away_wins',                                
'block_percentage',                         
'blocks' ,                                   
'defensive_rebounds',                        
'effective_field_goal_percentage',           
'field_goal_attempts',                       
'field_goal_percentage',                     
'field_goals',                               
'free_throw_attempt_rate',                  
'free_throw_attempts',                       
'free_throw_percentage',                     
'free_throws',                              
'free_throws_per_field_goal_attempt',       
'games_played',                             
'home_losses',                              
'home_wins',                                 
'losses',                                    
'minutes_played',                           
'net_rating',                                
'offensive_rating',                         
'offensive_rebound_percentage',             
'offensive_rebounds',                       
'opp_assist_percentage',                     
'opp_assists',                               
'opp_block_percentage',                      
'opp_blocks',                               
'opp_defensive_rebounds',                   
'opp_effective_field_goal_percentage',      
'opp_field_goal_attempts',                  
'opp_field_goal_percentage',                
'opp_field_goals' ,                         
'opp_free_throw_attempt_rate',              
'opp_free_throw_attempts',                 
'opp_free_throw_percentage',                
'opp_free_throws',                          
'opp_free_throws_per_field_goal_attempt' ,  
'opp_offensive_rating'  ,                    
'opp_offensive_rebound_percentage' ,        
'opp_offensive_rebounds',                    
'opp_personal_fouls',                       
'opp_points',                                
'opp_steal_percentage',                     
'opp_steals',                               
'opp_three_point_attempt_rate',             
'opp_three_point_field_goal_attempts',      
'opp_three_point_field_goal_percentage',     
'opp_three_point_field_goals',               
'opp_total_rebound_percentage',              
'opp_total_rebounds' ,                      
'opp_true_shooting_percentage' ,             
'opp_turnover_percentage' ,                 
'opp_turnovers',                            
'opp_two_point_field_goal_attempts',         
'opp_two_point_field_goal_percentage',     
'opp_two_point_field_goals',                
'pace'   ,                                  
'personal_fouls',                           
'points',                                    
'simple_rating_system',                    
'steal_percentage',                         
'steals',                                    
'strength_of_schedule',                     
'three_point_attempt_rate',                  
'three_point_field_goal_attempts',          
'three_point_field_goal_percentage',        
'three_point_field_goals',                  
'total_rebound_percentage',                  
'total_rebounds',                           
'true_shooting_percentage',                 
'turnover_percentage',                      
'turnovers',                                
'two_point_field_goal_attempts',            
'two_point_field_goal_percentage',          
'two_point_field_goals',                    
'win_percentage',                           
'wins']

# %%
cfirst_team_cols=['cfirst_'+s for s in team_columns]
clast_team_cols=['clast_'+s for s in team_columns]

# %%
#team_data=pd.DataFrame(columns=clast_team_cols)

for row in data.loc[393:,:].iterrows():
    clear_output(wait=True)
    print(row[0])
    temp=ncaa_teams(year=row[1].Year).__call__(row[1].college_code).dataframe.iloc[0,:]
    temp.index=['clast_'+s for s in list(temp.keys())]
    team_data=team_data.append(temp,sort=False)

team_data.head()
# Out:
# 393
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-57402fecfc9f> in <module>
#       4     clear_output(wait=True)
#       5     print(row[0])
# ----> 6     temp=ncaa_teams(year=row[1].Year).__call__(row[1].college_code).dataframe.iloc[0,:]
#       7     temp.index=['clast_'+s for s in list(temp.keys())]
#       8     team_data=team_data.append(temp,sort=False)
#
# ~\Anaconda3\lib\site-packages\sportsreference\ncaab\teams.py in dataframe(self)
#     221             'opp_three_point_field_goals': self.opp_three_point_field_goals,
#     222             'opp_two_point_field_goal_attempts':
# --> 223             self.opp_two_point_field_goal_attempts,
#     224             'opp_two_point_field_goal_percentage':
#     225             self.opp_two_point_field_goal_percentage,
#
# ~\Anaconda3\lib\site-packages\sportsreference\decorators.py in wrapper(*args)
#       6     @wraps(func)
#       7     def wrapper(*args):
# ----> 8         value = func(*args)
#       9         try:
#      10             return int(value)
#
# ~\Anaconda3\lib\site-packages\sportsreference\ncaab\teams.py in opp_two_point_field_goal_attempts(self)
#     627         """
#     628         return self.opp_field_goal_attempts - \
# --> 629             self.opp_three_point_field_goal_attempts
#     630
#     631     @float_property_decorator
#
# TypeError: unsupported operand type(s) for -: 'int' and 'NoneType'

# %%
row=data.loc[393,:]
ncaa_teams(year=2007).dataframes
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-546c701def80> in <module>
#       1 row=data.loc[393,:]
# ----> 2 ncaa_teams(year=2007).dataframes
#
# ~\Anaconda3\lib\site-packages\sportsreference\ncaab\teams.py in dataframes(self)
#    1149         frames = []
#    1150         for team in self.__iter__():
# -> 1151             frames.append(team.dataframe)
#    1152         return pd.concat(frames)
#
# ~\Anaconda3\lib\site-packages\sportsreference\ncaab\teams.py in dataframe(self)
#     221             'opp_three_point_field_goals': self.opp_three_point_field_goals,
#     222             'opp_two_point_field_goal_attempts':
# --> 223             self.opp_two_point_field_goal_attempts,
#     224             'opp_two_point_field_goal_percentage':
#     225             self.opp_two_point_field_goal_percentage,
#
# ~\Anaconda3\lib\site-packages\sportsreference\decorators.py in wrapper(*args)
#       6     @wraps(func)
#       7     def wrapper(*args):
# ----> 8         value = func(*args)
#       9         try:
#      10             return int(value)
#
# ~\Anaconda3\lib\site-packages\sportsreference\ncaab\teams.py in opp_two_point_field_goal_attempts(self)
#     627         """
#     628         return self.opp_field_goal_attempts - \
# --> 629             self.opp_three_point_field_goal_attempts
#     630
#     631     @float_property_decorator
#
# TypeError: unsupported operand type(s) for -: 'int' and 'NoneType'

# %%
team_data
# Out:
#                        clast_assist_percentage clast_assists  \
# ARIZONA                                   52.6           531
# DUKE                                      57.6           648
# MICHIGAN-STATE                            67.6           670
# OKLAHOMA                                  50.2           479
# TEXAS                                     44.7           394
# DUKE                                      57.6           648
# ALABAMA                                   50.3           458
# KENTUCKY                                  49.0           489
# VILLANOVA                                 53.7           655
# KENTUCKY                                  49.0           489
# MICHIGAN-STATE                            67.6           670
# BOSTON-COLLEGE                            51.9           492
# OREGON                                    56.4           556
# TEXAS-TECH                                54.9           529
# VILLANOVA                                 53.7           655
# MIAMI-FL                                  48.5           424
# MARYLAND                                  55.7           452
# GEORGIA-TECH                              54.3           409
# DUKE                                      57.6           648
# BOISE-STATE                               48.6           427
# UCLA                                      53.4           495
# MICHIGAN                                  53.6           585
# WICHITA-STATE                             63.7           610
# CINCINNATI                                60.4           570
# VILLANOVA                                 53.7           655
# WEST-VIRGINIA                             54.2           561
# VILLANOVA                                 53.7           655
# KANSAS                                    55.7           649
# TULANE                                    60.4           483
# DUKE                                      57.6           648
# ...                                        ...           ...
# NORTH-CAROLINA                            56.8           685
# LOUISVILLE                                62.4           625
# GONZAGA                                   52.9           512
# WAKE-FOREST                               44.7           405
# UCLA                                      55.9           541
# NORTH-CAROLINA                            56.8           685
# WAKE-FOREST                               44.7           405
# VIRGINIA-COMMONWEALTH                     54.2           469
# UCLA                                      55.9           541
# OHIO-STATE                                56.6           440
# SOUTHERN-CALIFORNIA                       50.2           438
# MISSOURI                                  62.2           699
# NORTH-CAROLINA                            56.8           685
# FLORIDA-STATE                             51.6           423
# CENTRAL-FLORIDA                           61.0           478
# VILLANOVA                                 55.7           551
# GEORGETOWN                                57.3           425
# PITTSBURGH                                60.9           633
# PITTSBURGH                                60.9           633
# WASHINGTON                                46.9           458
# XAVIER                                    54.8           464
# KENTUCKY                                  60.8           567
# ARKANSAS                                  48.9           390
# LOUISIANA-STATE                           56.5           529
# ARIZONA                                   55.7           500
# FLORIDA                                   59.4           605
# NORTH-CAROLINA                            56.8           685
# OKLAHOMA                                  53.1           521
# SAINT-MARYS-CA                            52.4           471
# TENNESSEE-MARTIN                          51.9           467
#
#                       clast_away_losses clast_away_wins  \
# ARIZONA                               3               8
# DUKE                                  5               6
# MICHIGAN-STATE                        1               8
# OKLAHOMA                              9               2
# TEXAS                                 7               3
# DUKE                                  5               6
# ALABAMA                               8               2
# KENTUCKY                              6               4
# VILLANOVA                             3               9
# KENTUCKY                              6               4
# MICHIGAN-STATE                        1               8
# BOSTON-COLLEGE                       11               2
# OREGON                                7               4
# TEXAS-TECH                            6               4
# VILLANOVA                             3               9
# MIAMI-FL                              4               8
# MARYLAND                              8               2
# GEORGIA-TECH                         10               1
# DUKE                                  5               6
# BOISE-STATE                           6               6
# UCLA                                  7               3
# MICHIGAN                              5               6
# WICHITA-STATE                         2               9
# CINCINNATI                            2               9
# VILLANOVA                             3               9
# WEST-VIRGINIA                         5               5
# VILLANOVA                             3               9
# KANSAS                                3               8
# TULANE                                8               3
# DUKE                                  5               6
# ...                                 ...             ...
# NORTH-CAROLINA                        2               8
# LOUISVILLE                            1               8
# GONZAGA                               1               9
# WAKE-FOREST                           4               7
# UCLA                                  4               6
# NORTH-CAROLINA                        2               8
# WAKE-FOREST                           4               7
# VIRGINIA-COMMONWEALTH                 6               7
# UCLA                                  4               6
# OHIO-STATE                            7               4
# SOUTHERN-CALIFORNIA                   8               2
# MISSOURI                              4               5
# NORTH-CAROLINA                        2               8
# FLORIDA-STATE                         5               8
# CENTRAL-FLORIDA                       8               3
# VILLANOVA                             3               8
# GEORGETOWN                            8               3
# PITTSBURGH                            2               7
# PITTSBURGH                            2               7
# WASHINGTON                            4               6
# XAVIER                                4               7
# KENTUCKY                              7               5
# ARKANSAS                              9               1
# LOUISIANA-STATE                       3               6
# ARIZONA                               9               2
# FLORIDA                               7               2
# NORTH-CAROLINA                        2               8
# OKLAHOMA                              3               7
# SAINT-MARYS-CA                        4               8
# TENNESSEE-MARTIN                      6               9
#
#                        clast_block_percentage clast_blocks  \
# ARIZONA                                  12.0          158
# DUKE                                     12.4          185
# MICHIGAN-STATE                           18.5          251
# OKLAHOMA                                 11.0          151
# TEXAS                                    12.8          168
# DUKE                                     12.4          185
# ALABAMA                                  14.7          192
# KENTUCKY                                 13.7          176
# VILLANOVA                                10.5          162
# KENTUCKY                                 13.7          176
# MICHIGAN-STATE                           18.5          251
# BOSTON-COLLEGE                            8.8          110
# OREGON                                   12.3          152
# TEXAS-TECH                               12.8          158
# VILLANOVA                                10.5          162
# MIAMI-FL                                 11.0          130
# MARYLAND                                 11.6          137
# GEORGIA-TECH                             14.3          171
# DUKE                                     12.4          185
# BOISE-STATE                               5.9           70
# UCLA                                     10.3          131
# MICHIGAN                                  8.1          126
# WICHITA-STATE                            11.1          127
# CINCINNATI                               15.8          194
# VILLANOVA                                10.5          162
# WEST-VIRGINIA                            15.9          192
# VILLANOVA                                10.5          162
# KANSAS                                   10.9          160
# TULANE                                   10.5          126
# DUKE                                     12.4          185
# ...                                       ...          ...
# NORTH-CAROLINA                            8.9          196
# LOUISVILLE                               11.7          223
# GONZAGA                                  10.0          174
# WAKE-FOREST                              10.2          176
# UCLA                                      6.8          110
# NORTH-CAROLINA                            8.9          196
# WAKE-FOREST                              10.2          176
# VIRGINIA-COMMONWEALTH                     9.4          155
# UCLA                                      6.8          110
# OHIO-STATE                               11.2          175
# SOUTHERN-CALIFORNIA                       9.7          165
# MISSOURI                                  7.2          140
# NORTH-CAROLINA                            8.9          196
# FLORIDA-STATE                            11.5          202
# CENTRAL-FLORIDA                           6.0           88
# VILLANOVA                                 7.0          128
# GEORGETOWN                                7.9          122
# TEXAS-TECH                                             0.511
# VILLANOVA                                              0.590
# MIAMI-FL                                               0.522
# MARYLAND                                               0.539
# GEORGIA-TECH                                           0.466
# DUKE                                                   0.560
# BOISE-STATE                                            0.522
# UCLA                                                   0.514
# MICHIGAN                                               0.552
# WICHITA-STATE                                          0.538
# CINCINNATI                                             0.502
# VILLANOVA                                              0.590
# WEST-VIRGINIA                                          0.488
# VILLANOVA                                              0.590
# KANSAS                                                 0.556
# TULANE                                                 0.509
# DUKE                                                   0.560
# ...                                                      ...
# NORTH-CAROLINA                                         0.515
# LOUISVILLE                                             0.511
# GONZAGA                                                0.535
# WAKE-FOREST                                            0.536
# UCLA                                                   0.535
# NORTH-CAROLINA                                         0.515
# WAKE-FOREST                                            0.536
# VIRGINIA-COMMONWEALTH                                  0.504
# UCLA                                                   0.535
# OHIO-STATE                                             0.539
# SOUTHERN-CALIFORNIA                                    0.513
# MISSOURI                                               0.527
# NORTH-CAROLINA                                         0.515
# FLORIDA-STATE                                          0.481
# CENTRAL-FLORIDA                                        0.503
# VILLANOVA                                              0.498
# GEORGETOWN                                             0.548
# PITTSBURGH                                             0.531
# PITTSBURGH                                             0.531
# WASHINGTON                                             0.488
# XAVIER                                                 0.491
# KENTUCKY                                               0.534
# ARKANSAS                                               0.491
# LOUISIANA-STATE                                        0.476
# ARIZONA                                                0.510
# FLORIDA                                                0.544
# NORTH-CAROLINA                                         0.515
# OKLAHOMA                                               0.566
# SAINT-MARYS-CA                                         0.501
# TENNESSEE-MARTIN                                       0.520
#
#                       clast_two_point_field_goals  clast_win_percentage  \
# ARIZONA                                       772                 0.771
# DUKE                                          816                 0.784
# MICHIGAN-STATE                                701                 0.857
# OKLAHOMA                                      654                 0.563
# TEXAS                                         637                 0.559
# DUKE                                          816                 0.784
# ALABAMA                                       681                 0.556
# KENTUCKY                                      803                 0.703
# VILLANOVA                                     756                 0.900
# KENTUCKY                                      803                 0.703
# MICHIGAN-STATE                                701                 0.857
# BOSTON-COLLEGE                                650                 0.543
# OREGON                                        662                 0.639
# TEXAS-TECH                                    712                 0.730
# VILLANOVA                                     756                 0.900
# MIAMI-FL                                      628                 0.688
# MARYLAND                                      582                 0.594
# GEORGIA-TECH                                  597                 0.406
# DUKE                                          816                 0.784
# BOISE-STATE                                   571                 0.719
# UCLA                                          617                 0.636
# MICHIGAN                                      731                 0.805
# WICHITA-STATE                                 657                 0.758
# CINCINNATI                                    682                 0.861
# VILLANOVA                                     756                 0.900
# WEST-VIRGINIA                                 714                 0.703
# VILLANOVA                                     756                 0.900
# KANSAS                                        774                 0.795
# TULANE                                        568                 0.452
# DUKE                                          816                 0.784
# ...                                           ...                   ...
# NORTH-CAROLINA                                941                 0.895
# LOUISVILLE                                    696                 0.838
# GONZAGA                                       716                 0.824
# WAKE-FOREST                                   780                 0.774
# UCLA                                          705                 0.743
# NORTH-CAROLINA                                941                 0.895
# WAKE-FOREST                                   780                 0.774
# VIRGINIA-COMMONWEALTH                         644                 0.706
# UCLA                                          705                 0.743
# OHIO-STATE                                    562                 0.667
# SOUTHERN-CALIFORNIA                           743                 0.629
# MISSOURI                                      861                 0.816
# NORTH-CAROLINA                                941                 0.895
# FLORIDA-STATE                                 604                 0.714
# CENTRAL-FLORIDA                               562                 0.548
# VILLANOVA                                     743                 0.789
# GEORGETOWN                                    551                 0.516
# PITTSBURGH                                    815                 0.861
# PITTSBURGH                                    815                 0.861
# WASHINGTON                                    831                 0.743
# XAVIER                                        608                 0.771
# KENTUCKY                                      731                 0.611
# ARKANSAS                                      595                 0.467
# LOUISIANA-STATE                               724                 0.771
# ARIZONA                                       685                 0.600
# FLORIDA                                       724                 0.694
# NORTH-CAROLINA                                941                 0.895
# OKLAHOMA                                      740                 0.833
# SAINT-MARYS-CA                                667                 0.800
# TENNESSEE-MARTIN                              651                 0.688
#
#                       clast_wins     clast_abbreviation clast_conference  \
# ARIZONA                       27                ARIZONA           pac-12
# DUKE                          29                   DUKE              acc
# MICHIGAN-STATE                30         MICHIGAN-STATE          big-ten
# OKLAHOMA                      18               OKLAHOMA           big-12
# TEXAS                         19                  TEXAS           big-12
# DUKE                          29                   DUKE              acc
# ALABAMA                       20                ALABAMA              sec
# KENTUCKY                      26               KENTUCKY              sec
# VILLANOVA                     36              VILLANOVA         big-east
# KENTUCKY                      26               KENTUCKY              sec
# MICHIGAN-STATE                30         MICHIGAN-STATE          big-ten
# BOSTON-COLLEGE                19         BOSTON-COLLEGE              acc
# OREGON                        23                 OREGON           pac-12
# TEXAS-TECH                    27             TEXAS-TECH           big-12
# VILLANOVA                     36              VILLANOVA         big-east
# MIAMI-FL                      22               MIAMI-FL              acc
# MARYLAND                      19               MARYLAND          big-ten
# GEORGIA-TECH                  13           GEORGIA-TECH              acc
# DUKE                          29                   DUKE              acc
# BOISE-STATE                   23            BOISE-STATE              mwc
# UCLA                          21                   UCLA           pac-12
# MICHIGAN                      33               MICHIGAN          big-ten
# WICHITA-STATE                 25          WICHITA-STATE              aac
# CINCINNATI                    31             CINCINNATI              aac
# VILLANOVA                     36              VILLANOVA         big-east
# WEST-VIRGINIA                 26          WEST-VIRGINIA           big-12
# VILLANOVA                     36              VILLANOVA         big-east
# KANSAS                        31                 KANSAS           big-12
# TULANE                        14                 TULANE              aac
# DUKE                          29                   DUKE              acc
# ...                          ...                    ...              ...
# NORTH-CAROLINA                34         NORTH-CAROLINA              acc
# LOUISVILLE                    31             LOUISVILLE         big-east
# GONZAGA                       28                GONZAGA              wcc
# WAKE-FOREST                   24            WAKE-FOREST              acc
# UCLA                          26                   UCLA           pac-10
# NORTH-CAROLINA                34         NORTH-CAROLINA              acc
# WAKE-FOREST                   24            WAKE-FOREST              acc
# VIRGINIA-COMMONWEALTH         24  VIRGINIA-COMMONWEALTH         colonial
# UCLA                          26                   UCLA           pac-10
# OHIO-STATE                    22             OHIO-STATE          big-ten
# SOUTHERN-CALIFORNIA           22    SOUTHERN-CALIFORNIA           pac-10
# MISSOURI                      31               MISSOURI           big-12
# NORTH-CAROLINA                34         NORTH-CAROLINA              acc
# KENTUCKY                                  8.0                   8.0
# ARKANSAS                                 14.0                   2.0
# LOUISIANA-STATE                           3.0                  13.0
# ARIZONA                                   9.0                   9.0
# FLORIDA                                   7.0                   9.0
# NORTH-CAROLINA                            3.0                  13.0
# OKLAHOMA                                  3.0                  13.0
# SAINT-MARYS-CA                            4.0                  10.0
# TENNESSEE-MARTIN                          4.0                  14.0
#
#                                   clast_name
# ARIZONA                              Arizona
# DUKE                                    Duke
# MICHIGAN-STATE                Michigan State
# OKLAHOMA                            Oklahoma
# TEXAS                                  Texas
# DUKE                                    Duke
# ALABAMA                              Alabama
# KENTUCKY                            Kentucky
# VILLANOVA                          Villanova
# KENTUCKY                            Kentucky
# MICHIGAN-STATE                Michigan State
# BOSTON-COLLEGE                Boston College
# OREGON                                Oregon
# TEXAS-TECH                        Texas Tech
# VILLANOVA                          Villanova
# MIAMI-FL                          Miami (FL)
# MARYLAND                            Maryland
# GEORGIA-TECH                    Georgia Tech
# DUKE                                    Duke
# BOISE-STATE                      Boise State
# UCLA                                    UCLA
# MICHIGAN                            Michigan
# WICHITA-STATE                  Wichita State
# CINCINNATI                        Cincinnati
# VILLANOVA                          Villanova
# WEST-VIRGINIA                  West Virginia
# VILLANOVA                          Villanova
# KANSAS                                Kansas
# TULANE                                Tulane
# DUKE                                    Duke
# ...                                      ...
# NORTH-CAROLINA                North Carolina
# LOUISVILLE                        Louisville
# GONZAGA                              Gonzaga
# WAKE-FOREST                      Wake Forest
# UCLA                                    UCLA
# NORTH-CAROLINA                North Carolina
# WAKE-FOREST                      Wake Forest
# VIRGINIA-COMMONWEALTH  Virginia Commonwealth
# UCLA                                    UCLA
# OHIO-STATE                        Ohio State
# SOUTHERN-CALIFORNIA      Southern California
# MISSOURI                            Missouri
# NORTH-CAROLINA                North Carolina
# FLORIDA-STATE                  Florida State
# CENTRAL-FLORIDA              Central Florida
# VILLANOVA                          Villanova
# GEORGETOWN                        Georgetown
# PITTSBURGH                        Pittsburgh
# PITTSBURGH                        Pittsburgh
# WASHINGTON                        Washington
# XAVIER                                Xavier
# KENTUCKY                            Kentucky
# ARKANSAS                            Arkansas
# LOUISIANA-STATE              Louisiana State
# ARIZONA                              Arizona
# FLORIDA                              Florida
# NORTH-CAROLINA                North Carolina
# OKLAHOMA                            Oklahoma
# SAINT-MARYS-CA             Saint Mary's (CA)
# TENNESSEE-MARTIN            Tennessee-Martin
#
# [393 rows x 84 columns]

# %%
team_data.to_csv('team_data.csv',index=False,header=True)

# %%
temp=ncaa_teams(year=row[1].Year).__call__(row[1].college_code).dataframe.iloc[0,:]
temp.index=['clast_'+s for s in list(temp.keys())]
team_data.append(temp,sort=False)
# Out:
#          cfirst_assist_percentage  cfirst_assists  cfirst_away_losses  \
# ARIZONA                       NaN             NaN                 NaN
#
#          cfirst_away_wins  cfirst_block_percentage  cfirst_blocks  \
# ARIZONA               NaN                      NaN            NaN
#
#          cfirst_defensive_rebounds  cfirst_effective_field_goal_percentage  \
# ARIZONA                        NaN                                     NaN
#
#          cfirst_field_goal_attempts  cfirst_field_goal_percentage  ...  \
# ARIZONA                         NaN                           NaN  ...
#
#          clast_two_point_field_goal_attempts  \
# ARIZONA                                 1361
#
#          clast_two_point_field_goal_percentage  clast_two_point_field_goals  \
# ARIZONA                                  0.567                          772
#
#          clast_win_percentage  clast_wins  clast_abbreviation  \
# ARIZONA                 0.771          27             ARIZONA
#
#          clast_conference  clast_conference_losses  clast_conference_wins  \
# ARIZONA            pac-12                      4.0                   14.0
#
#          clast_name
# ARIZONA     Arizona
#
# [1 rows x 163 columns]

# %%
temp.iloc[0,:].index
# Out:
# Index(['abbreviation', 'assist_percentage', 'assists', 'away_losses',
#        'away_wins', 'block_percentage', 'blocks', 'conference',
#        'conference_losses', 'conference_wins', 'defensive_rebounds',
#        'effective_field_goal_percentage', 'field_goal_attempts',
#        'field_goal_percentage', 'field_goals', 'free_throw_attempt_rate',
#        'free_throw_attempts', 'free_throw_percentage', 'free_throws',
#        'free_throws_per_field_goal_attempt', 'games_played', 'home_losses',
#        'home_wins', 'losses', 'minutes_played', 'name', 'net_rating',
#        'offensive_rating', 'offensive_rebound_percentage',
#        'offensive_rebounds', 'opp_assist_percentage', 'opp_assists',
#        'opp_block_percentage', 'opp_blocks', 'opp_defensive_rebounds',
#        'opp_effective_field_goal_percentage', 'opp_field_goal_attempts',
#        'opp_field_goal_percentage', 'opp_field_goals',
#        'opp_free_throw_attempt_rate', 'opp_free_throw_attempts',
#        'opp_free_throw_percentage', 'opp_free_throws',
#        'opp_free_throws_per_field_goal_attempt', 'opp_offensive_rating',
#        'opp_offensive_rebound_percentage', 'opp_offensive_rebounds',
#        'opp_personal_fouls', 'opp_points', 'opp_steal_percentage',
#        'opp_steals', 'opp_three_point_attempt_rate',
#        'opp_three_point_field_goal_attempts',
#        'opp_three_point_field_goal_percentage', 'opp_three_point_field_goals',
#        'opp_total_rebound_percentage', 'opp_total_rebounds',
#        'opp_true_shooting_percentage', 'opp_turnover_percentage',
#        'opp_turnovers', 'opp_two_point_field_goal_attempts',
#        'opp_two_point_field_goal_percentage', 'opp_two_point_field_goals',
#        'pace', 'personal_fouls', 'points', 'simple_rating_system',
#        'steal_percentage', 'steals', 'strength_of_schedule',
#        'three_point_attempt_rate', 'three_point_field_goal_attempts',
#        'three_point_field_goal_percentage', 'three_point_field_goals',
#        'total_rebound_percentage', 'total_rebounds',
#        'true_shooting_percentage', 'turnover_percentage', 'turnovers',
#        'two_point_field_goal_attempts', 'two_point_field_goal_percentage',
#        'two_point_field_goals', 'win_percentage', 'wins'],
#       dtype='object')

# %%
team_data_skinny=pd.read_excel('team_data/2018.xls',header=1)
team_data_skinny['Year']=2018
for i in range(2018,1992,-1):
    file='team_data/' + str(i) + '.xls'
    temp=pd.read_excel(file,header=1)
    temp['Year']=i
    team_data_skinny=team_data_skinny.append(temp,ignore_index=True)
team_data_skinny
# Out:
#        Rk                 School   G   W   L   W-L%    SRS    SOS   W.1   L.1  \
# 0       1      Abilene Christian  32  16  16  0.500  -9.14  -6.82   8.0  10.0
# 8848  ...  746  0.682    NaN  1185.0  489  225   80  488.0  555.0  1993
# 8849  ...  519  0.676    NaN   910.0  408  214   90  414.0  571.0  1993
# 8850  ...  754  0.725    NaN  1138.0  548  323   81  494.0  571.0  1993
# 8851  ...  673  0.664    NaN  1066.0  355  202  184  492.0  470.0  1993
# 8852  ...  594  0.690    NaN  1069.0  485  161  122  410.0  512.0  1993
# 8853  ...  460  0.626    NaN   819.0  271  155   67  368.0  464.0  1993
# 8854  ...  705  0.631    NaN   936.0  338  201   61  421.0  474.0  1993
#
# [8855 rows x 35 columns]

# %%
team_data_m=pd.read_excel('team_data/2018.xls',header=1)
team_data_m['Year']=2018
temp=pd.read_excel('team_data/2018a.xls',header=1)

merge_cols=list(set(temp.columns) - set(team_data_m.columns))+['Rk']

team_data_m=team_data_m.merge(temp[merge_cols] ,
                             how='outer',on='Rk',copy=False)

for i in range(2017,1992,-1):
    file='team_data/' + str(i) + '.xls'
    filea='team_data/' + str(i) + 'a.xls'
    temp=pd.read_excel(file,header=1)
    temp['Year']=i
    temp=temp.merge(pd.read_excel(filea,header=1)[merge_cols],
                             how='outer',on='Rk',copy=False)
    team_data_m=team_data_m.append(temp,ignore_index=True,sort=False)
team_data_m
# Out:
#        Rk                 School   G   W   L   W-L%    SRS    SOS   W.1   L.1  \
# 0       1      Abilene Christian  32  16  16  0.500  -9.14  -6.82   8.0  10.0
# 1       2              Air Force  31  12  19  0.387  -4.31   1.72   6.0  12.0
# 2       3                  Akron  32  14  18  0.438  -6.82  -1.92   6.0  12.0
# 3       4            Alabama A&M  31   3  28  0.097 -23.97  -8.04   3.0  15.0
# 4       5     Alabama-Birmingham  33  20  13  0.606   4.90  -0.65  10.0   8.0
# 5       6          Alabama State  31   8  23  0.258 -18.55  -8.62   8.0  10.0
# 6       7           Alabama NCAA  36  20  16  0.556  12.34  10.64   8.0  10.0
# 7       8            Albany (NY)  32  22  10  0.688   0.01  -5.41  10.0   6.0
# 8       9           Alcorn State  32  11  21  0.344 -18.07  -8.60   7.0  11.0
# 9      10               American  30   6  24  0.200 -14.63  -6.17   3.0  15.0
# 10     11      Appalachian State  33  15  18  0.455  -4.81  -2.65   9.0   9.0
# 11     12     Arizona State NCAA  32  20  12  0.625  14.37   6.56   8.0  10.0
# 12     13           Arizona NCAA  35  27   8  0.771  15.67   6.84  14.0   4.0
# 13     14            Little Rock  32   7  25  0.219 -10.44  -2.21   4.0  14.0
# 14     15    Arkansas-Pine Bluff  35  14  21  0.400 -14.84  -9.36  12.0   6.0
# 15     16         Arkansas State  32  11  21  0.344  -9.65  -3.02   6.0  12.0
# 16     17          Arkansas NCAA  35  23  12  0.657  14.76   9.85  10.0   8.0
# 17     18                   Army  30  13  17  0.433  -8.62  -7.17   6.0  12.0
# 18     19            Auburn NCAA  34  26   8  0.765  15.97   7.29  13.0   5.0
# 19     20            Austin Peay  34  19  15  0.559  -3.28  -2.49  12.0   6.0
# 20     21             Ball State  32  19  13  0.594  -1.22  -1.99  10.0   8.0
# ...   ...   ...   ...   ...   ...   ...    ...     ...   ...    ...   ...
# 8474  ...  53.6   NaN   NaN   NaN  11.7    NaN   0.256  51.8  0.532  19.0
# 8475  ...  59.5   NaN   NaN   NaN   7.7    NaN   0.319  49.3  0.487  19.0
# 8476  ...  62.5   NaN   NaN   NaN   9.2    NaN   0.272  53.4  0.547  16.3
# 8477  ...  56.9   NaN   NaN   NaN   4.1    NaN   0.244  45.2  0.535  16.8
# 8478  ...  58.5   NaN   NaN   NaN   6.6    NaN   0.298  50.7  0.567  17.1
# 8479  ...  49.6   NaN   NaN   NaN   5.2    NaN   0.258  47.4  0.467  17.9
# 8480  ...  63.3   NaN   NaN   NaN   9.6    NaN   0.266  48.9  0.505  19.0
# 8481  ...  62.3   NaN   NaN   NaN   9.4    NaN   0.177  51.5  0.529  17.1
# 8482  ...  48.7   NaN   NaN   NaN   7.0    NaN   0.241  46.1  0.445  18.8
# 8483  ...  51.5   NaN   NaN   NaN   9.3    NaN   0.248  46.0  0.451  17.3
# 8484  ...  56.9   NaN   NaN   NaN   8.2    NaN   0.242  52.5  0.477  16.6
# 8485  ...  64.4   NaN   NaN   NaN   9.1    NaN   0.269  49.2  0.508  19.6
# 8486  ...  59.1   NaN   NaN   NaN   6.9    NaN   0.283  53.5  0.544  17.7
# 8487  ...  57.7   NaN   NaN   NaN   7.3    NaN   0.262  52.5  0.534  17.6
# 8488  ...  49.7   NaN   NaN   NaN  10.3    NaN   0.245  52.1  0.487  18.8
# 8489  ...  56.9   NaN   NaN   NaN   5.1    NaN   0.299  52.9  0.521  20.6
# 8490  ...  60.1   NaN   NaN   NaN  11.0    NaN   0.285  49.3  0.483  16.5
# 8491  ...  63.2   NaN   NaN   NaN   8.6    NaN   0.184  48.1  0.471  19.6
# 8492  ...  60.5   NaN   NaN   NaN   7.9    NaN   0.240  48.1  0.503  20.2
# 8493  ...  52.5   NaN   NaN   NaN   9.3    NaN   0.267  53.1  0.529  17.8
# 8494  ...  51.5   NaN   NaN   NaN   9.0    NaN   0.273  47.5  0.492  18.7
# 8495  ...  57.5   NaN   NaN   NaN   7.2    NaN   0.228  50.4  0.500  21.6
# 8496  ...  57.5   NaN   NaN   NaN   6.2    NaN   0.331  48.5  0.496  17.6
# 8497  ...  54.6   NaN   NaN   NaN   5.4    NaN   0.265  50.6  0.520  17.6
# 8498  ...  51.5   NaN   NaN   NaN   7.0    NaN   0.200  46.6  0.515  17.1
# 8499  ...  55.5   NaN   NaN   NaN   6.2    NaN   0.286  54.5  0.556  17.9
# 8500  ...  51.4   NaN   NaN   NaN  13.9    NaN   0.289  50.4  0.477  20.9
# 8501  ...  57.7   NaN   NaN   NaN  10.0    NaN   0.244  53.0  0.542  17.3
# 8502  ...  53.3   NaN   NaN   NaN   8.1    NaN   0.238  51.2  0.464  20.5
# 8503  ...  51.1   NaN   NaN   NaN   4.6    NaN   0.276  46.0  0.440  17.8
#
# [8504 rows x 48 columns]

# %%
team_data_m['college_code']=team_data_m['School'].str.replace('University','')
team_data_m['college_code']=team_data_m['college_code'].str.replace('of ','')
team_data_m['college_code']=team_data_m['college_code'].str.replace(',','')
team_data_m['college_code']=team_data_m['college_code'].str.replace('.','')
team_data_m['college_code']=team_data_m['college_code'].str.replace('\'','')
team_data_m['college_code']=team_data_m['college_code'].str.replace('NCAA','')
team_data_m['college_code']=team_data_m['college_code'].str.replace('College','')
team_data_m['college_code']=team_data_m['college_code'].str.strip()
team_data_m['college_code']=team_data_m['college_code'].str.upper()
team_data_m['college_code']=team_data_m['college_code'].str.replace('   ','-')
team_data_m['college_code']=team_data_m['college_code'].str.replace('  ','-')
team_data_m['college_code']=team_data_m['college_code'].str.replace(' ','-')
team_data_m['college_code']=team_data_m['college_code'].str.replace('AT-','')
team_data_m['college_code']=team_data_m['college_code'].str.replace('CALIFORNIA-STATE','CAL-STATE')
team_data_m['college_code']=team_data_m['college_code'].str.replace('A&M','AM')
team_data_m['college_code']=team_data_m['college_code'].str.replace('THE-','')
team_data_m['college_code']=team_data_m['college_code'].str.replace('(','')
team_data_m['college_code']=team_data_m['college_code'].str.replace(')','')
team_data_m['college_code']=team_data_m['college_code'].str.replace('UC-','CALIFORNIA-')
team_data_m['college_code']=team_data_m['college_code'].str.replace('-&','')

# %%
code_set=set(college_teams.abbreviation)

for i in team_data_m[team_data_m.college_code=='CALIFORNIA-LOS-ANGELES'].index:
    team_data_m.loc[i,'college_code']='UCLA'

for i in team_data_m[team_data_m.college_code=='ILLINOIS-URBANA-CHAMPAIGN'].index:
    team_data_m.loc[i,'college_code']='ILLINOIS'
    
for i in team_data_m[team_data_m.college_code=='NEVADA-RENO'].index:
    team_data_m.loc[i,'college_code']='NEVADA'

for i in team_data_m[team_data_m.college_code=='GEORGIA-INSTITUTE-TECHNOLOGY'].index:
    team_data_m.loc[i,'college_code']='GEORGIA-TECH'    
    
for i in team_data_m[team_data_m.School=='Boston College'].index:
    team_data_m.loc[i,'college_code']='BOSTON-COLLEGE'    
    
for i in team_data_m[team_data_m.School=='Boston University'].index:
    team_data_m.loc[i,'college_code']='BOSTON-UNIVERSITY'  
    
for i in team_data_m[team_data_m.college_code=='VIRGINIA-POLYTECHNIC-INSTITUTE-AND-STATE'].index:
    team_data_m.loc[i,'college_code']='VIRGINIA-TECH'
    
for i in team_data_m[team_data_m.college_code=='TEXAS-AUSTIN'].index:
    team_data_m.loc[i,'college_code']='TEXAS'  

for i in team_data_m[team_data_m.college_code=='ST-JOHNS'].index:
    team_data_m.loc[i,'college_code']='ST-JOHNS-NY' 
    
for i in team_data_m[team_data_m.School=='University of Miami'].index:
    team_data_m.loc[i,'college_code']='MIAMI-FL'    
    
for i in team_data_m[team_data_m.School=='Miami University'].index:
    team_data_m.loc[i,'college_code']='MIAMI-OH' 
    
for i in team_data_m[team_data_m.college_code=='LOYOLA-CHICAGO'].index:
    team_data_m.loc[i,'college_code']='LOYOLA-IL'  

for i in team_data_m[team_data_m.college_code=='LOYOLA-IN-MARYLAND'].index:
    team_data_m.loc[i,'college_code']='LOYOLA-MD' 
    
for i in team_data_m[team_data_m.college_code=='FLORIDA-AGRICULTURAL-AND-MECHANICAL'].index:
    team_data_m.loc[i,'college_code']='FLORIDA-AM' 
    
for i in team_data_m[team_data_m.college_code=='CAL-STATE-FRESNO'].index:
    team_data_m.loc[i,'college_code']='FRESNO-STATE' 
    
for i in team_data_m[team_data_m.college_code=='CAL-STATE-LONG-BEACH'].index:
    team_data_m.loc[i,'college_code']='LONG-BEACH-STATE' 
    
for i in team_data_m[team_data_m.college_code=='TENNESSEE-TECHNOLOGICAL'].index:
    team_data_m.loc[i,'college_code']='TENNESSEE-TECH' 
    
for i in team_data_m[team_data_m.college_code=='INDIANA--PURDUE-INDIANAPOLIS'].index:
    team_data_m.loc[i,'college_code']='IUPUI' 
    
for i in team_data_m[team_data_m.college_code=='SAINT-MARYS-CALIFORNIA'].index:
    team_data_m.loc[i,'college_code']='SAINT-MARYS-CA' 
    
for i in team_data_m[team_data_m.college_code=='MIDDLE-TENNESSEE-STATE'].index:
    team_data_m.loc[i,'college_code']='MIDDLE-TENNESSEE' 
    
for i in team_data_m[team_data_m.college_code=='AUSTIN-PEAY-STATE'].index:
    team_data_m.loc[i,'college_code']='AUSTIN-PEAY'  
    
for i in team_data_m[team_data_m.college_code=='MASSACHUSETTS-AMHERST'].index:
    team_data_m.loc[i,'college_code']='MASSACHUSETTS'  
    
for i in team_data_m[team_data_m.college_code=='PENNSYLVANIA-STATE'].index:
    team_data_m.loc[i,'college_code']='PENN-STATE'
    
for i in team_data_m[team_data_m.college_code=='LONG-ISLAND'].index:
    team_data_m.loc[i,'college_code']='LONG-ISLAND-UNIVERSITY'
    
for i in team_data_m[team_data_m.college_code=='UNITED-STATES-NAVAL-ACADEMY'].index:
    team_data_m.loc[i,'college_code']='NAVY'
    
for code in team_data_m.college_code[team_data_m.Year == 2018]:
    if code not in code_set:
        print(code)
# Out:
# LITTLE-ROCK
# CHARLESTON
# PURDUE-FORT-WAYNE
# LOUISIANA
# OMAHA
# NORTH-CAROLINA-A&T
# SIU-EDWARDSVILLE
# TEXAS-RIO-GRANDE-VALLEY
# VMI

# %%
team_data_m=team_data_m.set_index(['Year','college_code'])

# %%
team_data_m=team_data_m.drop(columns=['Rk'])
team_data_m
# Out:
#                                            School   G   W   L   W-L%    SRS  \
# Year college_code
# 2018 ABILENE-CHRISTIAN          Abilene Christian  32  16  16  0.500  -9.14
#      AIR-FORCE                          Air Force  31  12  19  0.387  -4.31
#      AKRON                                  Akron  32  14  18  0.438  -6.82
#      ALABAMA-AM                       Alabama A&M  31   3  28  0.097 -23.97
#      ALABAMA-BIRMINGHAM        Alabama-Birmingham  33  20  13  0.606   4.90
#      ALABAMA-STATE                  Alabama State  31   8  23  0.258 -18.55
#      ALABAMA                         Alabama NCAA  36  20  16  0.556  12.34
#      ALBANY-NY                        Albany (NY)  32  22  10  0.688   0.01
#      ALCORN-STATE                    Alcorn State  32  11  21  0.344 -18.07
#      AMERICAN                            American  30   6  24  0.200 -14.63
#      APPALACHIAN-STATE          Appalachian State  33  15  18  0.455  -4.81
#      ARIZONA-STATE             Arizona State NCAA  32  20  12  0.625  14.37
#      ARIZONA                         Arizona NCAA  35  27   8  0.771  15.67
#      LITTLE-ROCK                      Little Rock  32   7  25  0.219 -10.44
#      ARKANSAS-PINE-BLUFF      Arkansas-Pine Bluff  35  14  21  0.400 -14.84
#      ARKANSAS-STATE                Arkansas State  32  11  21  0.344  -9.65
#      ARKANSAS                       Arkansas NCAA  35  23  12  0.657  14.76
#      ARMY                                    Army  30  13  17  0.433  -8.62
#      AUBURN                           Auburn NCAA  34  26   8  0.765  15.97
#      AUSTIN-PEAY                      Austin Peay  34  19  15  0.559  -3.28
#      BALL-STATE                        Ball State  32  19  13  0.594  -1.22
#      BAYLOR                                Baylor  34  19  15  0.559  14.59
#      BELMONT                              Belmont  33  24   9  0.727   5.54
#      BETHUNE-COOKMAN              Bethune-Cookman  32  18  14  0.563 -12.21
#      BINGHAMTON                        Binghamton  31  11  20  0.355 -10.29
#      BOISE-STATE                      Boise State  32  23   9  0.719  11.21
#      BOSTON-COLLEGE                Boston College  35  19  16  0.543   9.00
#      BOSTON-UNIVERSITY          Boston University  31  15  16  0.484  -8.34
#      BOWLING-GREEN-STATE      Bowling Green State  32  16  16  0.500  -6.38
#      BRADLEY                              Bradley  33  20  13  0.606   2.08
# ...                                           ...  ..  ..  ..    ...    ...
# 1993 UCLA                               UCLA NCAA  33  22  11  0.667  11.35
#      UTAH-STATE                        Utah State  27  10  17  0.370   1.19
#      UTAH                               Utah NCAA  31  24   7  0.774  13.34
#      VALPARAISO                        Valparaiso  28  12  16  0.429  -6.07
#      VANDERBILT                   Vanderbilt NCAA  34  28   6  0.824  19.82
#      VERMONT                              Vermont  27  10  17  0.370 -14.26
#      VILLANOVA                          Villanova  27   8  19  0.296   8.48
#      VIRGINIA-COMMONWEALTH  Virginia Commonwealth  30  20  10  0.667   9.26
#      VMI                                      VMI  27   5  22  0.185 -16.80
#      VIRGINIA-TECH                  Virginia Tech  28  10  18  0.357  -2.09
#      VIRGINIA                       Virginia NCAA  31  21  10  0.677  14.60
#      WAGNER                                Wagner  30  18  12  0.600  -6.68
#      WAKE-FOREST                 Wake Forest NCAA  30  21   9  0.700  16.82
#      WASHINGTON-STATE            Washington State  27  15  12  0.556  11.63
#      WASHINGTON                        Washington  27  13  14  0.481   4.94
#      WEBER-STATE                      Weber State  28  20   8  0.714   0.36
#      WEST-VIRGINIA                  West Virginia  29  17  12  0.586  11.82
#      WESTERN-CAROLINA            Western Carolina  27   6  21  0.222 -14.58
#      WESTERN-ILLINOIS            Western Illinois  27   7  20  0.259 -12.30
#      WESTERN-KENTUCKY       Western Kentucky NCAA  32  26   6  0.813  15.22
#      WESTERN-MICHIGAN            Western Michigan  29  17  12  0.586  -1.60
#      WICHITA-STATE                  Wichita State  27  10  17  0.370  -1.39
#      WILLIAM-MARY                  William & Mary  27  14  13  0.519  -2.51
#      WINTHROP                            Winthrop  30  14  16  0.467 -13.08
#      WISCONSIN                          Wisconsin  28  14  14  0.500   8.08
#      WRIGHT-STATE               Wright State NCAA  30  20  10  0.667   3.10
#      WYOMING                              Wyoming  28  13  15  0.464  -0.60
#      XAVIER                           Xavier NCAA  30  24   6  0.800  10.89
#      YALE                                    Yale  26  10  16  0.385  -8.84
#      YOUNGSTOWN-STATE            Youngstown State  26   3  23  0.115 -18.28
#
#                               SOS   W.1   L.1   W.2  ...  AST%  Pace  ORB%  \
# Year college_code                                    ...
# 2018 ABILENE-CHRISTIAN      -6.82   8.0  10.0   9.0  ...  55.4  71.6  27.8
#      AIR-FORCE               1.72   6.0  12.0   9.0  ...  60.7  67.7  27.5
#      AKRON                  -1.92   6.0  12.0  12.0  ...  52.7  69.1  27.1
#      ALABAMA-AM             -8.04   3.0  15.0   2.0  ...  50.5  68.3  29.4
#      ALABAMA-BIRMINGHAM     -0.65  10.0   8.0  14.0  ...  59.3  69.5  31.1
#      ALABAMA-STATE          -8.62   8.0  10.0   4.0  ...  41.7  70.5  31.9
#      ALABAMA                10.64   8.0  10.0  12.0  ...  50.3  70.2  29.3
#      ALBANY-NY              -5.41  10.0   6.0  14.0  ...  48.3  67.3  34.9
#      ALCORN-STATE           -8.60   7.0  11.0   9.0  ...  53.0  70.4  27.1
#      AMERICAN               -6.17   3.0  15.0   4.0  ...  52.6  67.4  23.4
#      APPALACHIAN-STATE      -2.65   9.0   9.0   9.0  ...  47.6  72.0  30.8
#      ARIZONA-STATE           6.56   8.0  10.0  13.0  ...  51.6  72.2  27.9
#      ARIZONA                 6.84  14.0   4.0  15.0  ...  52.6  68.7  33.2
#      LITTLE-ROCK            -2.21   4.0  14.0   5.0  ...  52.1  66.6  28.9
#      ARKANSAS-PINE-BLUFF    -9.36  12.0   6.0   7.0  ...  52.4  68.4  23.9
#      ARKANSAS-STATE         -3.02   6.0  12.0   7.0  ...  40.9  70.5  30.3
#      ARKANSAS                9.85  10.0   8.0  15.0  ...  49.9  71.3  28.7
#      ARMY                   -7.17   6.0  12.0   6.0  ...  61.1  71.7  27.0
#      AUBURN                  7.29  13.0   5.0  15.0  ...  53.1  73.5  31.8
#      AUSTIN-PEAY            -2.49  12.0   6.0  13.0  ...  49.5  70.1  35.7
#      BALL-STATE             -1.99  10.0   8.0  14.0  ...  52.9  71.1  27.8
#      BAYLOR                  9.17   8.0  10.0  15.0  ...  54.8  68.5  35.6
#      BELMONT                -2.88  15.0   3.0  14.0  ...  58.7  68.5  25.2
#      BETHUNE-COOKMAN       -12.48  12.0   4.0  10.0  ...  55.5  77.7  33.5
#      BINGHAMTON             -6.36   2.0  14.0   7.0  ...  47.8  67.9  26.0
#      BOISE-STATE             3.05  13.0   5.0  15.0  ...  48.6  70.7  29.3
#      BOSTON-COLLEGE          7.20   7.0  11.0  14.0  ...  51.9  70.1  29.8
#      BOSTON-UNIVERSITY      -5.84  10.0   8.0   6.0  ...  52.5  68.8  28.6
#      BOWLING-GREEN-STATE    -2.88   7.0  11.0   9.0  ...  51.4  71.9  30.0
#      BRADLEY                 0.36   9.0   9.0  13.0  ...  58.2  66.3  31.9
# ...                           ...   ...   ...   ...  ...   ...   ...   ...
# 1993 UCLA                    9.05  11.0   7.0   NaN  ...  53.6   NaN   NaN
#      UTAH-STATE              5.27   7.0  11.0   NaN  ...  59.5   NaN   NaN
#      UTAH                    2.27  15.0   3.0   NaN  ...  62.5   NaN   NaN
#      VALPARAISO             -4.89   7.0   9.0   NaN  ...  56.9   NaN   NaN
#      VANDERBILT              6.40  14.0   2.0   NaN  ...  58.5   NaN   NaN
#      VERMONT                -7.46   4.0  10.0   NaN  ...  49.6   NaN   NaN
#      VILLANOVA               7.18   3.0  15.0   NaN  ...  63.3   NaN   NaN
#      VIRGINIA-COMMONWEALTH   1.76   7.0   5.0   NaN  ...  62.3   NaN   NaN
#      VMI                    -5.03   3.0  15.0   NaN  ...  48.7   NaN   NaN
#      VIRGINIA-TECH           2.13   1.0  11.0   NaN  ...  51.5   NaN   NaN
#      VIRGINIA                9.76   9.0   7.0   NaN  ...  56.9   NaN   NaN
#      WAGNER                 -8.94  12.0   6.0   NaN  ...  64.4   NaN   NaN
#      WAKE-FOREST             9.32  10.0   6.0   NaN  ...  59.1   NaN   NaN
#      WASHINGTON-STATE        5.63   9.0   9.0   NaN  ...  57.7   NaN   NaN
#      WASHINGTON              6.26   7.0  11.0   NaN  ...  49.7   NaN   NaN
#      WEBER-STATE            -3.89  10.0   4.0   NaN  ...  56.9   NaN   NaN
#      WEST-VIRGINIA           6.20   7.0   7.0   NaN  ...  60.1   NaN   NaN
#      WESTERN-CAROLINA       -6.04   2.0  16.0   NaN  ...  63.2   NaN   NaN
#      WESTERN-ILLINOIS       -5.72   4.0  12.0   NaN  ...  60.5   NaN   NaN
#      WESTERN-KENTUCKY        1.75  14.0   4.0   NaN  ...  52.5   NaN   NaN
#      WESTERN-MICHIGAN       -2.32  12.0   6.0   NaN  ...  51.5   NaN   NaN
#      WICHITA-STATE           4.30   7.0  11.0   NaN  ...  57.5   NaN   NaN
#      WILLIAM-MARY           -1.43   6.0   8.0   NaN  ...  57.5   NaN   NaN
#      WINTHROP              -11.40   5.0  11.0   NaN  ...  54.6   NaN   NaN
#      WISCONSIN               6.72   7.0  11.0   NaN  ...  51.5   NaN   NaN
#      WRIGHT-STATE           -5.97  10.0   6.0   NaN  ...  55.5   NaN   NaN
#      WYOMING                 1.28   7.0  11.0   NaN  ...  51.4   NaN   NaN
#      XAVIER                  2.75  12.0   2.0   NaN  ...  57.7   NaN   NaN
#      YALE                   -7.08   6.0   8.0   NaN  ...  53.3   NaN   NaN
#      YOUNGSTOWN-STATE       -5.98   1.0  15.0   NaN  ...  51.1   NaN   NaN
#
#                             STL%  BLK%   ORtg  FT/FGA  TRB%   eFG%  TOV%
# Year college_code
# 2018 ABILENE-CHRISTIAN      11.3  11.6  102.2   0.217  49.7  0.521  17.7
#      AIR-FORCE               9.5   8.1  100.8   0.233  48.7  0.490  16.3
#      AKRON                   8.4   7.5  102.6   0.222  49.2  0.518  17.3
#      ALABAMA-AM              5.8   3.9   88.1   0.203  48.2  0.450  20.9
#      ALABAMA-BIRMINGHAM      7.7  11.6  109.8   0.218  54.8  0.545  16.5
#      ALABAMA-STATE           7.7  11.2   97.0   0.227  47.9  0.465  16.9
#      ALABAMA                 9.0  14.7  103.0   0.281  50.3  0.519  17.8
#      ALBANY-NY               7.0   7.9  110.3   0.279  55.2  0.507  14.7
#      ALCORN-STATE            8.8   7.7   99.2   0.232  48.4  0.499  17.9
#      AMERICAN               10.7   9.1   96.6   0.202  45.1  0.506  18.3
#      APPALACHIAN-STATE       8.2   8.9  104.6   0.252  52.3  0.509  16.3
#      ARIZONA-STATE           9.0   9.9  113.6   0.303  49.0  0.538  13.0
#      ARIZONA                 7.1  12.0  115.6   0.281  55.6  0.563  15.3
#      LITTLE-ROCK             7.4   9.5   94.2   0.192  49.1  0.484  18.5
#      ARKANSAS-PINE-BLUFF    11.4  11.7   95.7   0.247  43.6  0.496  18.6
#      ARKANSAS-STATE          9.5   7.9  104.2   0.236  48.6  0.502  15.9
#      ARKANSAS                8.6  13.8  111.8   0.255  48.9  0.538  13.2
#      ARMY                    7.9   8.2  103.2   0.160  49.6  0.524  16.4
#      AUBURN                 10.1  15.2  111.4   0.308  51.7  0.508  14.1
#      AUSTIN-PEAY             9.4   8.9  104.7   0.239  52.2  0.505  16.8
#      BALL-STATE              7.4   8.9  104.6   0.239  51.1  0.516  16.1
#      BAYLOR                  7.9  12.2  109.1   0.234  54.2  0.523  16.7
#      BELMONT                 7.1   6.5  113.3   0.206  51.5  0.588  16.3
#      BETHUNE-COOKMAN         8.1   8.9  104.6   0.282  52.1  0.502  17.3
#      BINGHAMTON              8.0  11.6  101.6   0.190  49.6  0.510  15.8
#      BOISE-STATE             8.0   5.9  108.8   0.231  55.9  0.542  16.5
#      BOSTON-COLLEGE          7.1   8.8  107.7   0.228  51.6  0.521  15.5
#      BOSTON-UNIVERSITY      10.7   9.8  102.5   0.206  50.1  0.529  17.6
#      BOWLING-GREEN-STATE     8.1   6.6  103.6   0.272  51.2  0.483  15.0
#      BRADLEY                 9.8  12.9  101.7   0.263  51.8  0.490  17.3
# ...                          ...   ...    ...     ...   ...    ...   ...
# 1993 UCLA                    NaN  11.7    NaN   0.256  51.8  0.532  19.0
#      UTAH-STATE              NaN   7.7    NaN   0.319  49.3  0.487  19.0
#      UTAH                    NaN   9.2    NaN   0.272  53.4  0.547  16.3
#      VALPARAISO              NaN   4.1    NaN   0.244  45.2  0.535  16.8
#      VANDERBILT              NaN   6.6    NaN   0.298  50.7  0.567  17.1
#      VERMONT                 NaN   5.2    NaN   0.258  47.4  0.467  17.9
#      VILLANOVA               NaN   9.6    NaN   0.266  48.9  0.505  19.0
#      VIRGINIA-COMMONWEALTH   NaN   9.4    NaN   0.177  51.5  0.529  17.1
#      VMI                     NaN   7.0    NaN   0.241  46.1  0.445  18.8
#      VIRGINIA-TECH           NaN   9.3    NaN   0.248  46.0  0.451  17.3
#      VIRGINIA                NaN   8.2    NaN   0.242  52.5  0.477  16.6
#      WAGNER                  NaN   9.1    NaN   0.269  49.2  0.508  19.6
#      WAKE-FOREST             NaN   6.9    NaN   0.283  53.5  0.544  17.7
#      WASHINGTON-STATE        NaN   7.3    NaN   0.262  52.5  0.534  17.6
#      WASHINGTON              NaN  10.3    NaN   0.245  52.1  0.487  18.8
#      WEBER-STATE             NaN   5.1    NaN   0.299  52.9  0.521  20.6
#      WEST-VIRGINIA           NaN  11.0    NaN   0.285  49.3  0.483  16.5
#      WESTERN-CAROLINA        NaN   8.6    NaN   0.184  48.1  0.471  19.6
#      WESTERN-ILLINOIS        NaN   7.9    NaN   0.240  48.1  0.503  20.2
#      WESTERN-KENTUCKY        NaN   9.3    NaN   0.267  53.1  0.529  17.8
#      WESTERN-MICHIGAN        NaN   9.0    NaN   0.273  47.5  0.492  18.7
#      WICHITA-STATE           NaN   7.2    NaN   0.228  50.4  0.500  21.6
#      WILLIAM-MARY            NaN   6.2    NaN   0.331  48.5  0.496  17.6
#      WINTHROP                NaN   5.4    NaN   0.265  50.6  0.520  17.6
#      WISCONSIN               NaN   7.0    NaN   0.200  46.6  0.515  17.1
#      WRIGHT-STATE            NaN   6.2    NaN   0.286  54.5  0.556  17.9
#      WYOMING                 NaN  13.9    NaN   0.289  50.4  0.477  20.9
#      XAVIER                  NaN  10.0    NaN   0.244  53.0  0.542  17.3
#      YALE                    NaN   8.1    NaN   0.238  51.2  0.464  20.5
#      YOUNGSTOWN-STATE        NaN   4.6    NaN   0.276  46.0  0.440  17.8
#
# [8504 rows x 46 columns]

# %%
team_data_fat=pd.read_excel('team_data/2018.xls',header=1)
team_data_fat['Year']=2018

temp1=pd.read_excel('team_data/2018a.xls',header=1)
merge_cols_a=list(set(temp1.columns) - set(team_data_fat.columns))+['Rk']
team_data_fat=team_data_fat.merge(temp1[merge_cols_a] ,
                             how='outer',on='Rk',copy=False)

temp2=pd.read_excel('team_data/2018o.xls',header=1)
merge_cols_o=list(set(temp2.columns) - set(team_data_fat.columns))+['Rk']
temp2.columns = ['opp_' + col for col in temp2.columns]########################################Only rename new columns
team_data_fat=team_data_fat.merge(temp2[merge_cols_o] ,
                             how='outer',on='Rk',copy=False)

temp3=pd.read_excel('team_data/2018ao.xls',header=1)
temp3.columns = ['opp_' + col for col in temp3.columns]
merge_cols_ao=list(set(temp3.columns) - set(team_data_fat.columns))+['Rk']
team_data_fat=team_data_fat.merge(temp3[merge_cols_ao] ,
                             how='outer',on='Rk',copy=False)


for i in range(2017,2009,-1):
    file='team_data/' + str(i) + '.xls'
    file_a='team_data/' + str(i) + 'a.xls'
    file_o='team_data/' + str(i) + 'o.xls'
    file_ao='team_data/' + str(i) + 'ao.xls'
    
    temp=pd.read_excel(file,header=1)
    temp['Year']=i
    temp=temp.merge(pd.read_excel(file_a,header=1)[merge_cols_a],
                             how='outer',on='Rk',copy=False)
    temp2=pd.read_excel(file_o,header=1)
    temp2=
    temp=temp.merge([merge_cols_o],
                             how='outer',on='Rk',copy=False)
    temp=temp.merge(pd.read_excel(file_ao,header=1)[merge_cols_ao],
                             how='outer',on='Rk',copy=False)
    
    team_data_fat=team_data_fat.append(temp,ignore_index=True,sort=False)
team_data_fat
# Out:
#        Rk                 School   G   W   L   W-L%    SRS    SOS   W.1   L.1  \
# 0       1      Abilene Christian  32  16  16  0.500  -9.14  -6.82   8.0  10.0
# 3109  ...  51.0  68.5  33.2   9.3   8.1  109.9   0.304  52.0  0.516  15.4
# 3110  ...  62.5  64.0  42.0   8.6  11.4  111.4   0.279  54.5  0.489  14.8
# 3111  ...  50.6  70.1  34.9  13.5   9.2  106.0   0.216  50.3  0.516  16.7
# 3112  ...  52.1  62.4  27.8  10.5  11.7   94.2   0.269  48.4  0.460  17.8
# 3113  ...  50.1  65.8  34.3   9.6   7.7  106.6   0.249  51.8  0.513  16.6
# 3114  ...  53.1  66.6  37.2  10.5   7.1  104.0   0.298  52.5  0.482  17.2
# 3115  ...  59.5  64.6  34.7  10.4   8.7  107.0   0.280  53.8  0.508  17.2
# 3116  ...  63.0  61.4  30.7   8.6   7.3  107.5   0.259  49.6  0.510  14.9
# 3117  ...  47.1  66.7  34.1  12.8  11.8   92.0   0.232  51.0  0.412  15.1
# 3118  ...  53.1  59.8  30.2   9.4   9.5  111.3   0.238  51.3  0.514  12.5
# 3119  ...  56.8  65.1  33.6  10.6   5.8  105.4   0.296  52.2  0.495  15.5
# 3120  ...  57.7  62.9  31.6   9.4   6.3  107.0   0.250  49.7  0.514  16.0
# 3121  ...  47.1  72.1  29.0  10.7  11.4   97.6   0.348  48.1  0.480  18.7
# 3122  ...  51.4  69.7  35.2   9.3   8.9  111.0   0.298  53.5  0.522  15.3
# 3123  ...  54.4  67.6  33.1  10.1  11.0   98.2   0.301  50.2  0.462  18.0
# 3124  ...  56.0  67.5  32.4   8.9  10.4   98.5   0.275  49.7  0.467  16.9
#
# [3125 rows x 48 columns]

# %%
team_data_m.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 8504 entries, (2018, ABILENE-CHRISTIAN) to (1993, YOUNGSTOWN-STATE)
# Data columns (total 46 columns):
# School         8504 non-null object
# G              8504 non-null int64
# W              8504 non-null int64
# L              8504 non-null int64
# W-L%           8504 non-null float64
# SRS            8495 non-null float64
# SOS            8495 non-null float64
# W.1            8420 non-null float64
# L.1            8420 non-null float64
# W.2            6059 non-null float64
# L.2            6059 non-null float64
# W.3            6059 non-null float64
# L.3            6059 non-null float64
# Tm.            8504 non-null int64
# Opp.           8501 non-null float64
# Unnamed: 16    0 non-null float64
# MP             4685 non-null float64
# FG             8504 non-null int64
# FGA            8504 non-null int64
# FG%            8504 non-null float64
# 3P             8504 non-null int64
# 3PA            8504 non-null int64
# 3P%            8504 non-null float64
# FT             8504 non-null int64
# FTA            8504 non-null int64
# FT%            8504 non-null float64
# ORB            7264 non-null float64
# TRB            8503 non-null float64
# AST            8504 non-null int64
# STL            8504 non-null int64
# BLK            8504 non-null int64
# TOV            8475 non-null float64
# PF             8165 non-null float64
# 3PAr           8504 non-null float64
# TS%            8504 non-null float64
# FTr            8504 non-null float64
# AST%           8504 non-null float64
# Pace           3148 non-null float64
# ORB%           4679 non-null float64
# STL%           4638 non-null float64
# BLK%           8486 non-null float64
# ORtg           4638 non-null float64
# FT/FGA         8504 non-null float64
# TRB%           8486 non-null float64
# eFG%           8504 non-null float64
# TOV%           8475 non-null float64
# dtypes: float64(32), int64(13), object(1)
# memory usage: 3.0+ MB

# %%
missing_map=sns.heatmap(team_data_m.isnull(), cbar=False)

# %%
drop_cols=['W.2','L.2','W.3','L.3','Unnamed: 16','MP','ORB','Pace','ORB%','STL%','ORtg']
team_data_m=team_data_m.drop(columns=drop_cols)
missing_map=sns.heatmap(team_data_m.isnull(), cbar=False)

# %%
team_data_m.columns=['team_' + col for col in team_data_m.columns]

# %%
data=data.merge(team_data_m, how='left',on=['Year','college_code'])

# %%
missing_map=sns.heatmap(data.isnull(), cbar=False)

# %%
skinny_columns=list(filter(lambda col: data[col].isnull().sum()<100, list(data.columns)))
skinny_columns
# Out:
# ['Year',
#  'Rd',
#  'Pk',
#  'Tm',
#  'Player',
#  'Age',
#  'Pos',
#  'Born',
#  'College',
#  'From',
#  'To',
#  'G',
#  'MP',
#  'PTS',
#  'TRB',
#  'AST',
#  'STL',
#  'BLK',
#  'FG%',
#  '2P%',
#  '3P%',
#  'FT%',
#  'WS',
#  'WS/48',
#  'college_code',
#  'cfirst_assists',
#  'cfirst_blocks',
#  'cfirst_effective_field_goal_percentage',
#  'cfirst_field_goal_attempts',
#  'cfirst_field_goal_percentage',
#  'cfirst_field_goals',
#  'cfirst_free_throw_attempt_rate',
#  'cfirst_free_throw_attempts',
#  'cfirst_free_throw_percentage',
#  'cfirst_free_throws',
#  'cfirst_games_played',
#  'cfirst_minutes_played',
#  'cfirst_personal_fouls',
#  'cfirst_points',
#  'cfirst_steals',
#  'cfirst_three_point_attempt_rate',
#  'cfirst_three_point_attempts',
#  'cfirst_three_point_percentage',
#  'cfirst_three_pointers',
#  'cfirst_total_rebounds',
#  'cfirst_true_shooting_percentage',
#  'cfirst_turnover_percentage',
#  'cfirst_turnovers',
#  'cfirst_two_point_attempts',
#  'cfirst_two_point_percentage',
#  'cfirst_two_pointers',
#  'clast_assists',
#  'clast_blocks',
#  'clast_effective_field_goal_percentage',
#  'clast_field_goal_attempts',
#  'clast_field_goal_percentage',
#  'clast_field_goals',
#  'clast_free_throw_attempt_rate',
#  'clast_free_throw_attempts',
#  'clast_free_throw_percentage',
#  'clast_free_throws',
#  'clast_games_played',
#  'clast_minutes_played',
#  'clast_personal_fouls',
#  'clast_points',
#  'clast_steals',
#  'clast_three_point_attempt_rate',
#  'clast_three_point_attempts',
#  'clast_three_point_percentage',
#  'clast_three_pointers',
#  'clast_total_rebounds',
#  'clast_true_shooting_percentage',
#  'clast_turnover_percentage',
#  'clast_turnovers',
#  'clast_two_point_attempts',
#  'clast_two_point_percentage',
#  'clast_two_pointers']

# %%
medium_columns=list(filter(lambda col: data[col].isnull().sum()<300, list(data.columns)))
medium_columns
# Out:
# ['Year',
#  'Rd',
#  'Pk',
#  'Tm',
#  'Player',
#  'Age',
#  'Pos',
#  'Born',
#  'College',
#  'From',
#  'To',
#  'G',
#  'MP',
#  'PTS',
#  'TRB',
#  'AST',
#  'STL',
#  'BLK',
#  'FG%',
#  '2P%',
#  '3P%',
#  'FT%',
#  'WS',
#  'WS/48',
#  'college_code',
#  'cfirst_assists',
#  'cfirst_blocks',
#  'cfirst_effective_field_goal_percentage',
#  'cfirst_field_goal_attempts',
#  'cfirst_field_goal_percentage',
#  'cfirst_field_goals',
#  'cfirst_free_throw_attempt_rate',
#  'cfirst_free_throw_attempts',
#  'cfirst_free_throw_percentage',
#  'cfirst_free_throws',
#  'cfirst_games_played',
#  'cfirst_games_started',
#  'cfirst_minutes_played',
#  'cfirst_personal_fouls',
#  'cfirst_points',
#  'cfirst_steals',
#  'cfirst_three_point_attempt_rate',
#  'cfirst_three_point_attempts',
#  'cfirst_three_point_percentage',
#  'cfirst_three_pointers',
#  'cfirst_total_rebounds',
#  'cfirst_true_shooting_percentage',
#  'cfirst_turnover_percentage',
#  'cfirst_turnovers',
#  'cfirst_two_point_attempts',
#  'cfirst_two_point_percentage',
#  'cfirst_two_pointers',
#  'clast_assists',
#  'clast_blocks',
#  'clast_effective_field_goal_percentage',
#  'clast_field_goal_attempts',
#  'clast_field_goal_percentage',
#  'clast_field_goals',
#  'clast_free_throw_attempt_rate',
#  'clast_free_throw_attempts',
#  'clast_free_throw_percentage',
#  'clast_free_throws',
#  'clast_games_played',
#  'clast_games_started',
#  'clast_minutes_played',
#  'clast_personal_fouls',
#  'clast_points',
#  'clast_steals',
#  'clast_three_point_attempt_rate',
#  'clast_three_point_attempts',
#  'clast_three_point_percentage',
#  'clast_three_pointers',
#  'clast_total_rebounds',
#  'clast_true_shooting_percentage',
#  'clast_turnover_percentage',
#  'clast_turnovers',
#  'clast_two_point_attempts',
#  'clast_two_point_percentage',
#  'clast_two_pointers',
#  'team_School',
#  'team_G',
#  'team_W',
#  'team_L',
#  'team_W-L%',
#  'team_SRS',
#  'team_SOS',
#  'team_W.1',
#  'team_L.1',
#  'team_Tm.',
#  'team_Opp.',
#  'team_FG',
#  'team_FGA',
#  'team_FG%',
#  'team_3P',
#  'team_3PA',
#  'team_3P%',
#  'team_FT',
#  'team_FTA',
#  'team_FT%',
#  'team_TRB',
#  'team_AST',
#  'team_STL',
#  'team_BLK',
#  'team_TOV',
#  'team_PF',
#  'team_3PAr',
#  'team_TS%',
#  'team_FTr',
#  'team_AST%',
#  'team_BLK%',
#  'team_FT/FGA',
#  'team_TRB%',
#  'team_eFG%',
#  'team_TOV%']

# %%
fat_columns=list(filter(lambda col: data[col].isnull().sum()<900, list(data.columns)))
fat_columns
# Out:
# ['Year',
#  'Rd',
#  'Pk',
#  'Tm',
#  'Player',
#  'Age',
#  'Pos',
#  'Born',
#  'College',
#  'From',
#  'To',
#  'G',
#  'MP',
#  'PTS',
#  'TRB',
#  'AST',
#  'STL',
#  'BLK',
#  'FG%',
#  '2P%',
#  '3P%',
#  'FT%',
#  'WS',
#  'WS/48',
#  'college_code',
#  'cfirst_assist_percentage',
#  'cfirst_assists',
#  'cfirst_block_percentage',
#  'cfirst_blocks',
#  'cfirst_box_plus_minus',
#  'cfirst_defensive_box_plus_minus',
#  'cfirst_defensive_rebound_percentage',
#  'cfirst_defensive_rebounds',
#  'cfirst_defensive_win_shares',
#  'cfirst_effective_field_goal_percentage',
#  'cfirst_field_goal_attempts',
#  'cfirst_field_goal_percentage',
#  'cfirst_field_goals',
#  'cfirst_free_throw_attempt_rate',
#  'cfirst_free_throw_attempts',
#  'cfirst_free_throw_percentage',
#  'cfirst_free_throws',
#  'cfirst_games_played',
#  'cfirst_games_started',
#  'cfirst_minutes_played',
#  'cfirst_offensive_box_plus_minus',
#  'cfirst_offensive_rebound_percentage',
#  'cfirst_offensive_rebounds',
#  'cfirst_offensive_win_shares',
#  'cfirst_personal_fouls',
#  'cfirst_player_efficiency_rating',
#  'cfirst_points',
#  'cfirst_points_produced',
#  'cfirst_steal_percentage',
#  'cfirst_steals',
#  'cfirst_three_point_attempt_rate',
#  'cfirst_three_point_attempts',
#  'cfirst_three_point_percentage',
#  'cfirst_three_pointers',
#  'cfirst_total_rebound_percentage',
#  'cfirst_total_rebounds',
#  'cfirst_true_shooting_percentage',
#  'cfirst_turnover_percentage',
#  'cfirst_turnovers',
#  'cfirst_two_point_attempts',
#  'cfirst_two_point_percentage',
#  'cfirst_two_pointers',
#  'cfirst_usage_percentage',
#  'cfirst_win_shares',
#  'cfirst_win_shares_per_40_minutes',
#  'clast_assist_percentage',
#  'clast_assists',
#  'clast_block_percentage',
#  'clast_blocks',
#  'clast_box_plus_minus',
#  'clast_defensive_box_plus_minus',
#  'clast_defensive_rebound_percentage',
#  'clast_defensive_rebounds',
#  'clast_defensive_win_shares',
#  'clast_effective_field_goal_percentage',
#  'clast_field_goal_attempts',
#  'clast_field_goal_percentage',
#  'clast_field_goals',
#  'clast_free_throw_attempt_rate',
#  'clast_free_throw_attempts',
#  'clast_free_throw_percentage',
#  'clast_free_throws',
#  'clast_games_played',
#  'clast_games_started',
#  'clast_minutes_played',
#  'clast_offensive_box_plus_minus',
#  'clast_offensive_rebound_percentage',
#  'clast_offensive_rebounds',
#  'clast_offensive_win_shares',
#  'clast_personal_fouls',
#  'clast_player_efficiency_rating',
#  'clast_points',
#  'clast_points_produced',
#  'clast_steal_percentage',
#  'clast_steals',
#  'clast_three_point_attempt_rate',
#  'clast_three_point_attempts',
#  'clast_three_point_percentage',
#  'clast_three_pointers',
#  'clast_total_rebound_percentage',
#  'clast_total_rebounds',
#  'clast_true_shooting_percentage',
#  'clast_turnover_percentage',
#  'clast_turnovers',
#  'clast_two_point_attempts',
#  'clast_two_point_percentage',
#  'clast_two_pointers',
#  'clast_usage_percentage',
#  'clast_win_shares',
#  'clast_win_shares_per_40_minutes',
#  'team_School',
#  'team_G',
#  'team_W',
#  'team_L',
#  'team_W-L%',
#  'team_SRS',
#  'team_SOS',
#  'team_W.1',
#  'team_L.1',
#  'team_Tm.',
#  'team_Opp.',
#  'team_FG',
#  'team_FGA',
#  'team_FG%',
#  'team_3P',
#  'team_3PA',
#  'team_3P%',
#  'team_FT',
#  'team_FTA',
#  'team_FT%',
#  'team_TRB',
#  'team_AST',
#  'team_STL',
#  'team_BLK',
#  'team_TOV',
#  'team_PF',
#  'team_3PAr',
#  'team_TS%',
#  'team_FTr',
#  'team_AST%',
#  'team_BLK%',
#  'team_FT/FGA',
#  'team_TRB%',
#  'team_eFG%',
#  'team_TOV%']
